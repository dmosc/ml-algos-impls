# %%
def predict(row, coefs):
  y = coefs[0] # first coefficient refers to b0 (bias, y-intercept)
  
  for i in range(len(row) - 1):
    y += coefs[i + 1] * row[i]
  
  return y


def coefficients_sgd(train, learning_rate, epochs):
  coefs = [0.0] * len(train[0])
  
  for epoch in range(epochs):
    error_sum = 0
    for row in train:
      y = predict(row, coefs)
      error = y - row[-1]
      error_sum += pow(error, 2)
      coefs[0] = coefs[0] - learning_rate * error
      for i in range(len(row) - 1):
        coefs[i + 1] = coefs[i + 1] - learning_rate * error * row[i]
    print(f"epoch={epoch}; lrate={learning_rate}; error={error_sum}")
  
  return coefs


dataset = [[1, 1], [2, 3], [4, 3], [3, 2], [5, 5]]
learning_rate = 0.001
epochs = 50
coefs = coefficients_sgd(train=dataset, learning_rate=learning_rate, epochs=epochs)
display(coefs)
# Out:
# epoch=0; lrate=0.001; error=46.23569225016471
# epoch=1; lrate=0.001; error=41.305142323835085
# epoch=2; lrate=0.001; error=36.92968879875065
# epoch=3; lrate=0.001; error=33.046843407651664
# epoch=4; lrate=0.001; error=29.601151923716085
# epoch=5; lrate=0.001; error=26.543402390484545
# epoch=6; lrate=0.001; error=23.82992247422831
# epoch=7; lrate=0.001; error=21.421955907121237
# epoch=8; lrate=0.001; error=19.285109118735654
# epoch=9; lrate=0.001; error=17.38886015544335
# epoch=10; lrate=0.001; error=15.706122876572774
# epoch=11; lrate=0.001; error=14.212860205347214
# epoch=12; lrate=0.001; error=12.88774091297372
# epoch=13; lrate=0.001; error=11.7118350357667
# epoch=14; lrate=0.001; error=10.668343576747102
# epoch=15; lrate=0.001; error=9.742358632631682
# epoch=16; lrate=0.001; error=8.920650521505976
# epoch=17; lrate=0.001; error=8.191478871959525
# epoch=18; lrate=0.001; error=7.544424976557279
# epoch=19; lrate=0.001; error=6.970243016110007
# epoch=20; lrate=0.001; error=6.4607280306236845
# epoch=21; lrate=0.001; error=6.00859875189941
# epoch=22; lrate=0.001; error=5.607393624934783
# epoch=23; lrate=0.001; error=5.251378533574368
# epoch=24; lrate=0.001; error=4.935464912958705
# epoch=25; lrate=0.001; error=4.6551370796144145
# epoch=26; lrate=0.001; error=4.40638774162885
# epoch=27; lrate=0.001; error=4.185660768141068
# epoch=28; lrate=0.001; error=3.9898004010231354
# epoch=29; lrate=0.001; error=3.8160061836022887
# epoch=30; lrate=0.001; error=3.6617929628979957
# epoch=31; lrate=0.001; error=3.5249553942839214
# epoch=32; lrate=0.001; error=3.4035364417673994
# epoch=33; lrate=0.001; error=3.295799424125944
# epoch=34; lrate=0.001; error=3.2002032077659255
# epoch=35; lrate=0.001; error=3.1153801920958983
# epoch=36; lrate=0.001; error=3.0401167730772007
# epoch=37; lrate=0.001; error=2.9733360059968246
# epoch=38; lrate=0.001; error=2.914082219907388
# epoch=39; lrate=0.001; error=2.8615073640442605
# epoch=40; lrate=0.001; error=2.8148588912588495
# epoch=41; lrate=0.001; error=2.7734690054522004
# epoch=42; lrate=0.001; error=2.736745119468375
# epoch=43; lrate=0.001; error=2.7041613871898917
# epoch=44; lrate=0.001; error=2.6752511889152393
# epoch=45; lrate=0.001; error=2.649600462709536
# epoch=46; lrate=0.001; error=2.6268417864985882
# epoch=47; lrate=0.001; error=2.606649126395945
# epoch=48; lrate=0.001; error=2.5887331762654906
# epoch=49; lrate=0.001; error=2.572837221964086
# [0.22998234937311363, 0.8017220304137576]

# %%
from csv import reader
from random import seed, randrange
from math import sqrt


seed(42)


def load_csv(filepath):
  dataset = []
  
  with open(filepath, "r") as file:
    csv_reader = reader(file)
    for row in csv_reader:
      if row:
        dataset.append(row)
  
  return dataset


def str_col_to_float(dataset, col):
  for row in dataset:
    row[col] = float(row[col].strip())


def dataset_minmax(dataset):
  minmax = []

  for i in range(len(dataset[0])):
    col_vals = [row[i] for row in dataset]
    minmax.append([min(col_vals), max(col_vals)])

  return minmax


def normalize_dataset(dataset):
  minmax = dataset_minmax(dataset)
  
  for row in dataset:
    for i in range(len(row)):
      row[i] = (row[i] - minmax[i][0]) / (minmax[i][1] - minmax[i][0])
    

def cross_validation_split(dataset, folds):
  dataset_split = []
  _dataset = dataset.copy()
  dataset_split_size = int(len(dataset) / folds)

  for _ in range(folds):
    fold = []
    while len(fold) < dataset_split_size:
      idx = randrange(len(_dataset))
      fold.append(_dataset.pop(idx))
    dataset_split.append(fold)
  
  return dataset_split


def rmse_metric(actual, predicted):
  assert len(actual) == len(predicted)

  error_sum_sq = sum(map(lambda a, p: pow(p - a, 2), actual, predicted))
  mean_error = error_sum_sq / float(len(actual))

  return sqrt(mean_error)


def evaluate_algorithm(dataset, algorithm, folds, *args):
  folds = cross_validation_split(dataset=dataset, folds=folds)
  scores = []
  
  for fold in folds:
    train = folds.copy()
    train.remove(fold)
    train = sum(train, [])
    test = []
    for row in fold:
      row_copy = row.copy()
      row_copy[-1] = None
      test.append(row_copy)
    predicted = algorithm(train, test, *args)
    actual = list(map(lambda row: row[-1], fold))
    rmse = rmse_metric(actual=actual, predicted=predicted)
    scores.append(rmse)
  
  return scores


def linear_regression_algorithm_with_sdg(train, test, learning_rate, epochs):
  predictions = []
  coefs = coefficients_sgd(train=train, learning_rate=learning_rate, epochs=epochs)
  
  for row in test:
    yhat = predict(row=row, coefs=coefs)
    predictions.append(yhat)
  
  return predictions

# %%
filepath = "../datasets/wine-quality-white.csv"
dataset = load_csv(filepath=filepath)
for i in range(len(dataset[0])):
  str_col_to_float(dataset=dataset, col=i)
normalize_dataset(dataset=dataset)
scores = evaluate_algorithm(dataset, linear_regression_algorithm_with_sdg, 5, 0.01, 50)
display(f"scores: {scores}; mean_rsme={sum(scores) / float(len(scores))}")
# Out:
# epoch=0; lrate=0.01; error=78.44145597829196
# epoch=1; lrate=0.01; error=67.08865711810463
# epoch=2; lrate=0.01; error=65.57214322521925
# epoch=3; lrate=0.01; error=64.72768916656149
# epoch=4; lrate=0.01; error=64.22769714871525
# epoch=5; lrate=0.01; error=63.92180281142388
# epoch=6; lrate=0.01; error=63.728334313520534
# epoch=7; lrate=0.01; error=63.60188382479972
# epoch=8; lrate=0.01; error=63.5165259056815
# epoch=9; lrate=0.01; error=63.45702565414449
# epoch=10; lrate=0.01; error=63.41417762390333
# epoch=11; lrate=0.01; error=63.38227650905153
# epoch=12; lrate=0.01; error=63.35770614688372
# epoch=13; lrate=0.01; error=63.33812952925595
# epoch=14; lrate=0.01; error=63.32201073889288
# epoch=15; lrate=0.01; error=63.30832543914003
# epoch=16; lrate=0.01; error=63.296381471496304
# epoch=17; lrate=0.01; error=63.28570544047876
# epoch=18; lrate=0.01; error=63.275969783710586
# epoch=19; lrate=0.01; error=63.266945198056895
# epoch=20; lrate=0.01; error=63.25846922935466
# epoch=21; lrate=0.01; error=63.25042532047126
# epoch=22; lrate=0.01; error=63.24272871098534
# epoch=23; lrate=0.01; error=63.235316872548665
# epoch=24; lrate=0.01; error=63.22814297322824
# epoch=25; lrate=0.01; error=63.22117137987705
# epoch=26; lrate=0.01; error=63.21437454085562
# epoch=27; lrate=0.01; error=63.20773080928134
# epoch=28; lrate=0.01; error=63.201222910774575
# epoch=29; lrate=0.01; error=63.19483685531818
# epoch=30; lrate=0.01; error=63.18856115691542
# epoch=31; lrate=0.01; error=63.18238626788468
# epoch=32; lrate=0.01; error=63.17630416381987
# epoch=33; lrate=0.01; error=63.170308035111596
# epoch=34; lrate=0.01; error=63.16439205445992
# epoch=35; lrate=0.01; error=63.158551199094276
# epoch=36; lrate=0.01; error=63.15278111279409
# epoch=37; lrate=0.01; error=63.147077997207944
# epoch=38; lrate=0.01; error=63.14143852500757
# epoch=39; lrate=0.01; error=63.13585976955062
# epoch=40; lrate=0.01; error=63.13033914719605
# epoch=41; lrate=0.01; error=63.12487436945949
# epoch=42; lrate=0.01; error=63.119463402937704
# epoch=43; lrate=0.01; error=63.114104435448475
# epoch=44; lrate=0.01; error=63.108795847216534
# epoch=45; lrate=0.01; error=63.103536186195626
# epoch=46; lrate=0.01; error=63.09832414683163
# epoch=47; lrate=0.01; error=63.093158551708726
# epoch=48; lrate=0.01; error=63.08803833562825
# epoch=49; lrate=0.01; error=63.08296253176861
# epoch=0; lrate=0.01; error=77.23979990307961
# epoch=1; lrate=0.01; error=65.56603743666523
# epoch=2; lrate=0.01; error=64.04929474175553
# epoch=3; lrate=0.01; error=63.21856103421886
# epoch=4; lrate=0.01; error=62.726498394558455
# epoch=5; lrate=0.01; error=62.4239337053683
# epoch=6; lrate=0.01; error=62.23141612588563
# epoch=7; lrate=0.01; error=62.10494782116299
# epoch=8; lrate=0.01; error=62.019339655124114
# epoch=9; lrate=0.01; error=61.959687675418124
# epoch=10; lrate=0.01; error=61.9169004792389
# epoch=11; lrate=0.01; error=61.88528172612118
# epoch=12; lrate=0.01; error=61.86118033982343
# epoch=13; lrate=0.01; error=61.84221171983907
# epoch=14; lrate=0.01; error=61.826794158243956
# epoch=15; lrate=0.01; error=61.81386497936937
# epoch=16; lrate=0.01; error=61.80270241753197
# epoch=17; lrate=0.01; error=61.79281152882757
# epoch=18; lrate=0.01; error=61.783849881915145
# epoch=19; lrate=0.01; error=61.77557850025362
# epoch=20; lrate=0.01; error=61.76782912200498
# epoch=21; lrate=0.01; error=61.760482157425486
# epoch=22; lrate=0.01; error=61.753451740402085
# epoch=23; lrate=0.01; error=61.746675527944774
# epoch=24; lrate=0.01; error=61.74010770094346
# epoch=25; lrate=0.01; error=61.73371413648776
# epoch=26; lrate=0.01; error=61.72746906081564
# epoch=27; lrate=0.01; error=61.72135271636407
# epoch=28; lrate=0.01; error=61.715349726276315
# epoch=29; lrate=0.01; error=61.709447940525095
# epoch=30; lrate=0.01; error=61.70363761597472
# epoch=31; lrate=0.01; error=61.69791082899411
# epoch=32; lrate=0.01; error=61.69226105078742
# epoch=33; lrate=0.01; error=61.68668283719442
# epoch=34; lrate=0.01; error=61.68117159950764
# epoch=35; lrate=0.01; error=61.67572343303291
# epoch=36; lrate=0.01; error=61.670334987134616
# epoch=37; lrate=0.01; error=61.66500336535847
# epoch=38; lrate=0.01; error=61.65972604758423
# epoch=39; lrate=0.01; error=61.6545008284975
# epoch=40; lrate=0.01; error=61.649325768302575
# epoch=41; lrate=0.01; error=61.64419915273638
# epoch=42; lrate=0.01; error=61.63911946024849
# epoch=43; lrate=0.01; error=61.63408533477856
# epoch=44; lrate=0.01; error=61.629095562969475
# epoch=45; lrate=0.01; error=61.62414905493637
# epoch=46; lrate=0.01; error=61.61924482792932
# epoch=47; lrate=0.01; error=61.61438199237354
# epoch=48; lrate=0.01; error=61.60955973988137
# epoch=49; lrate=0.01; error=61.60477733292275
# epoch=0; lrate=0.01; error=79.52498792216306
# epoch=1; lrate=0.01; error=67.51050748936177
# epoch=2; lrate=0.01; error=65.78317336777802
# epoch=3; lrate=0.01; error=64.84598033246
# epoch=4; lrate=0.01; error=64.30063186853766
# epoch=5; lrate=0.01; error=63.9709696230098
# epoch=6; lrate=0.01; error=63.76450537660573
# epoch=7; lrate=0.01; error=63.63083043173114
# epoch=8; lrate=0.01; error=63.54154383467825
# epoch=9; lrate=0.01; error=63.48010813018347
# epoch=10; lrate=0.01; error=63.436588570227656
# epoch=11; lrate=0.01; error=63.404845573859504
# epoch=12; lrate=0.01; error=63.380989701162584
# epoch=13; lrate=0.01; error=63.36250425272187
# epoch=14; lrate=0.01; error=63.34773141687158
# epoch=15; lrate=0.01; error=63.335562515179355
# epoch=16; lrate=0.01; error=63.32524637571136
# epoch=17; lrate=0.01; error=63.316268096012934
# epoch=18; lrate=0.01; error=63.30827088083494
# epoch=19; lrate=0.01; error=63.30100486223188
# epoch=20; lrate=0.01; error=63.29429315993369
# epoch=21; lrate=0.01; error=63.28800913932839
# epoch=22; lrate=0.01; error=63.28206103990286
# epoch=23; lrate=0.01; error=63.276381507561304
# epoch=24; lrate=0.01; error=63.27092041832428
# epoch=25; lrate=0.01; error=63.26563992709614
# epoch=26; lrate=0.01; error=63.2605110298563
# epoch=27; lrate=0.01; error=63.25551116079575
# epoch=28; lrate=0.01; error=63.250622500753835
# epoch=29; lrate=0.01; error=63.2458307769052
# epoch=30; lrate=0.01; error=63.24112440344803
# epoch=31; lrate=0.01; error=63.23649386026728
# epoch=32; lrate=0.01; error=63.23193123867745
# epoch=33; lrate=0.01; error=63.22742990525696
# epoch=34; lrate=0.01; error=63.22298424978948
# epoch=35; lrate=0.01; error=63.218589493629594
# epoch=36; lrate=0.01; error=63.21424154191248
# epoch=37; lrate=0.01; error=63.20993686792144
# epoch=38; lrate=0.01; error=63.205672421331805
# epoch=39; lrate=0.01; error=63.201445554412416
# epoch=40; lrate=0.01; error=63.19725396192524
# epoch=41; lrate=0.01; error=63.19309563161259
# epoch=42; lrate=0.01; error=63.18896880299534
# epoch=43; lrate=0.01; error=63.18487193277898
# epoch=44; lrate=0.01; error=63.18080366558354
# epoch=45; lrate=0.01; error=63.17676280902116
# epoch=46; lrate=0.01; error=63.172748312356816
# epoch=47; lrate=0.01; error=63.168759248154444
# epoch=48; lrate=0.01; error=63.164794796436546
# epoch=49; lrate=0.01; error=63.1608542309656
# epoch=0; lrate=0.01; error=78.02794028346496
# epoch=1; lrate=0.01; error=66.31220611010568
# epoch=2; lrate=0.01; error=64.65717316215506
# epoch=3; lrate=0.01; error=63.73669915952407
# epoch=4; lrate=0.01; error=63.18960468522065
# epoch=5; lrate=0.01; error=62.852694764124244
# epoch=6; lrate=0.01; error=62.63828620357894
# epoch=7; lrate=0.01; error=62.49757932474289
# epoch=8; lrate=0.01; error=62.40253679815674
# epoch=9; lrate=0.01; error=62.33653795597976
# epoch=10; lrate=0.01; error=62.28943935494011
# epoch=11; lrate=0.01; error=62.254887990811405
# epoch=12; lrate=0.01; error=62.228814398712345
# epoch=13; lrate=0.01; error=62.20856129106559
# epoch=14; lrate=0.01; error=62.192364840155825
# epoch=15; lrate=0.01; error=62.179037585317026
# epoch=16; lrate=0.01; error=62.167770005715084
# epoch=17; lrate=0.01; error=62.15800383584965
# epoch=18; lrate=0.01; error=62.149349810608356
# epoch=19; lrate=0.01; error=62.141533504572465
# epoch=20; lrate=0.01; error=62.1343592521653
# epoch=21; lrate=0.01; error=62.1276858761001
# epoch=22; lrate=0.01; error=62.121410221420135
# epoch=23; lrate=0.01; error=62.11545590093512
# epoch=24; lrate=0.01; error=62.10976554903919
# epoch=25; lrate=0.01; error=62.104295454127474
# epoch=26; lrate=0.01; error=62.09901181361686
# epoch=27; lrate=0.01; error=62.093888102087924
# epoch=28; lrate=0.01; error=62.0889032071254
# epoch=29; lrate=0.01; error=62.084040097460914
# epoch=30; lrate=0.01; error=62.07928486224803
# epoch=31; lrate=0.01; error=62.07462601066037
# epoch=32; lrate=0.01; error=62.07005395529782
# epoch=33; lrate=0.01; error=62.06556062633753
# epoch=34; lrate=0.01; error=62.06113917947829
# epoch=35; lrate=0.01; error=62.05678377179478
# epoch=36; lrate=0.01; error=62.05248938729176
# epoch=37; lrate=0.01; error=62.048251699243416
# epoch=38; lrate=0.01; error=62.044066960113426
# epoch=39; lrate=0.01; error=62.0399319124204
# epoch=40; lrate=0.01; error=62.03584371573551
# epoch=41; lrate=0.01; error=62.03179988627198
# epoch=42; lrate=0.01; error=62.0277982464468
# epoch=43; lrate=0.01; error=62.02383688243264
# epoch=44; lrate=0.01; error=62.01991410820017
# epoch=45; lrate=0.01; error=62.016028434882855
# epoch=46; lrate=0.01; error=62.012178544560115
# epoch=47; lrate=0.01; error=62.008363267729294
# epoch=48; lrate=0.01; error=62.00458156389281
# epoch=49; lrate=0.01; error=62.00083250478096
# epoch=0; lrate=0.01; error=78.3393696975679
# epoch=1; lrate=0.01; error=66.65706839432944
# epoch=2; lrate=0.01; error=65.02385256028502
# epoch=3; lrate=0.01; error=64.14331233647995
# epoch=4; lrate=0.01; error=63.63188309109094
# epoch=5; lrate=0.01; error=63.322223130199234
# epoch=6; lrate=0.01; error=63.127463215896356
# epoch=7; lrate=0.01; error=63.00062988238638
# epoch=8; lrate=0.01; error=62.915367437164804
# epoch=9; lrate=0.01; error=62.85633183527491
# epoch=10; lrate=0.01; error=62.814273811157356
# epoch=11; lrate=0.01; error=62.783442787254764
# epoch=12; lrate=0.01; error=62.76016816153405
# epoch=13; lrate=0.01; error=62.74205575882364
# epoch=14; lrate=0.01; error=62.72751645685902
# epoch=15; lrate=0.01; error=62.715480544475575
# epoch=16; lrate=0.01; error=62.705219620093565
# epoch=17; lrate=0.01; error=62.69623284767285
# epoch=18; lrate=0.01; error=62.68817288468488
# epoch=19; lrate=0.01; error=62.68079689222568
# epoch=20; lrate=0.01; error=62.6739337368941
# epoch=21; lrate=0.01; error=62.667461821039346
# epoch=22; lrate=0.01; error=62.66129398164218
# epoch=23; lrate=0.01; error=62.65536713873045
# epoch=24; lrate=0.01; error=62.64963516081769
# epoch=25; lrate=0.01; error=62.64406392330055
# epoch=26; lrate=0.01; error=62.63862786955401
# epoch=27; lrate=0.01; error=62.63330760631078
# epoch=28; lrate=0.01; error=62.628088213729114
# epoch=29; lrate=0.01; error=62.622958051164126
# epoch=30; lrate=0.01; error=62.617907908010174
# epoch=31; lrate=0.01; error=62.61293039570046
# epoch=32; lrate=0.01; error=62.60801950893345
# epoch=33; lrate=0.01; error=62.60317030621965
# epoch=34; lrate=0.01; error=62.598378674989505
# epoch=35; lrate=0.01; error=62.59364115700659
# epoch=36; lrate=0.01; error=62.588954817075205
# epoch=37; lrate=0.01; error=62.5843171430788
# epoch=38; lrate=0.01; error=62.579725968896994
# epoch=39; lrate=0.01; error=62.57517941418747
# epoch=40; lrate=0.01; error=62.5706758367438
# epoch=41; lrate=0.01; error=62.56621379433641
# epoch=42; lrate=0.01; error=62.56179201379093
# epoch=43; lrate=0.01; error=62.5574093656692
# epoch=44; lrate=0.01; error=62.5530648433312
# epoch=45; lrate=0.01; error=62.5487575454794
# epoch=46; lrate=0.01; error=62.5444866614891
# epoch=47; lrate=0.01; error=62.54025145901062
# epoch=48; lrate=0.01; error=62.53605127342652
# epoch=49; lrate=0.01; error=62.531885498850784
# 'scores: [0.12353443065407795, 0.1299033492359778, 0.12357271484541896, 0.12802250691031047, 0.12599780793314658]; mean_rsme=0.12620616191578632'
