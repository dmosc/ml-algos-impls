# %%
from csv import reader
from random import seed, randrange


seed(42)


def load_csv(filepath):
  dataset = []

  with open(filepath, "r") as file:
    csv_reader = reader(file)
    for row in csv_reader:
      if row:
        dataset.append(row)
  
  return dataset


def str_col_to_float(dataset, col):
  for row in dataset:
    row[col] = float(row[col].strip())


def str_col_to_int(dataset, col):
  class_vals = set(list(map(lambda row: row[col], dataset)))
  class_idx_map = dict()

  for idx, cv in enumerate(class_vals):
    class_idx_map[cv] = idx
  for row in dataset:
    row[col] = class_idx_map[row[col]]


def cross_validation_split(dataset, n_folds):
  dataset_folds = []
  fold_size = int(len(dataset) / n_folds)
  dataset_ = dataset.copy()

  for _ in range(n_folds):
    fold = []
    while len(fold) < fold_size:
      fold.append(dataset_.pop(randrange(len(dataset_))))
    dataset_folds.append(fold)
  
  return dataset_folds


def accuracy_metric(actual, predicted):
  assert len(actual) == len(predicted)

  size = len(actual)
  correct_count = 0

  for i in range(size):
    correct_count += 1 if actual[i] == predicted[i] else 0
  
  return (correct_count / float(size)) * 100


def evaluate_algorithm(dataset, algorithm, n_folds, *args):
  folds = cross_validation_split(dataset=dataset, n_folds=n_folds)
  scores = []

  for fold in folds:
    train = folds.copy()
    train.remove(fold)
    train = sum(train, [])
    test = []
    for row in fold:
      row_ = row.copy()
      row_[-1] = None
      test.append(row_)
    predicted = algorithm(train, test, *args)
    actual = list(map(lambda row: row[-1], fold))
    accuracy = accuracy_metric(actual=actual, predicted=predicted)
    scores.append(accuracy)
  
  return scores


def predict(row, weights):
  activation = weights[0]
  
  for i in range(len(row) - 1):
    activation += weights[i + 1] * row[i]
  
  return 1 if activation >= 0 else 0


def train_weights(train, l_rate, n_epochs):
  weights = [0.0] * len(train[0])

  for epoch in range(n_epochs):
    epoch_error = 0.0
    for row in train:
      prediction = predict(row, weights)
      error = row[-1] - prediction
      epoch_error += pow(error, 2)
      weights[0] = weights[0] + l_rate * error
      for i in range(len(row) - 1):
        weights[i + 1] = weights[i + 1] + l_rate * error * row[i]
    print(f"epoch={epoch}; l_rate={l_rate}; error={epoch_error}")
  
  return weights


def perceptron(train, test, l_rate, n_epochs):
  predictions = []
  weights = train_weights(train=train, l_rate=l_rate, n_epochs=n_epochs)
  
  for row in test:
    predictions.append(predict(row=row, weights=weights))
  
  return predictions


filepath = "../datasets/sonar.csv"
dataset = load_csv(filepath=filepath)
n_folds = 3
l_rate = 0.01
n_epochs = 1000

for i in range(len(dataset[0]) - 1):
  str_col_to_float(dataset=dataset, col=i)
str_col_to_int(dataset=dataset, col=len(dataset[0]) - 1)
scores = evaluate_algorithm(dataset, perceptron, n_folds, l_rate, n_epochs)
display(f"scores={scores}")
display(f"mean accuracy={sum(scores) / len(scores)}")
# Out:
# epoch=0; l_rate=0.01; error=61.0
# epoch=1; l_rate=0.01; error=55.0
# epoch=2; l_rate=0.01; error=53.0
# epoch=3; l_rate=0.01; error=46.0
# epoch=4; l_rate=0.01; error=45.0
# epoch=5; l_rate=0.01; error=52.0
# epoch=6; l_rate=0.01; error=45.0
# epoch=7; l_rate=0.01; error=41.0
# epoch=8; l_rate=0.01; error=42.0
# epoch=9; l_rate=0.01; error=44.0
# epoch=10; l_rate=0.01; error=39.0
# epoch=11; l_rate=0.01; error=38.0
# epoch=12; l_rate=0.01; error=44.0
# epoch=13; l_rate=0.01; error=33.0
# epoch=14; l_rate=0.01; error=40.0
# epoch=15; l_rate=0.01; error=39.0
# epoch=16; l_rate=0.01; error=43.0
# epoch=17; l_rate=0.01; error=34.0
# epoch=18; l_rate=0.01; error=38.0
# epoch=19; l_rate=0.01; error=34.0
# epoch=20; l_rate=0.01; error=40.0
# epoch=21; l_rate=0.01; error=36.0
# epoch=22; l_rate=0.01; error=36.0
# epoch=23; l_rate=0.01; error=42.0
# epoch=24; l_rate=0.01; error=34.0
# epoch=25; l_rate=0.01; error=37.0
# epoch=26; l_rate=0.01; error=40.0
# epoch=27; l_rate=0.01; error=34.0
# epoch=28; l_rate=0.01; error=43.0
# epoch=29; l_rate=0.01; error=36.0
# epoch=30; l_rate=0.01; error=48.0
# epoch=31; l_rate=0.01; error=34.0
# epoch=32; l_rate=0.01; error=41.0
# epoch=33; l_rate=0.01; error=36.0
# epoch=34; l_rate=0.01; error=32.0
# epoch=35; l_rate=0.01; error=38.0
# epoch=36; l_rate=0.01; error=32.0
# epoch=37; l_rate=0.01; error=32.0
# epoch=38; l_rate=0.01; error=36.0
# epoch=39; l_rate=0.01; error=37.0
# epoch=40; l_rate=0.01; error=34.0
# epoch=41; l_rate=0.01; error=32.0
# epoch=42; l_rate=0.01; error=28.0
# epoch=43; l_rate=0.01; error=33.0
# epoch=44; l_rate=0.01; error=30.0
# epoch=45; l_rate=0.01; error=32.0
# epoch=46; l_rate=0.01; error=27.0
# epoch=47; l_rate=0.01; error=36.0
# epoch=48; l_rate=0.01; error=32.0
# epoch=49; l_rate=0.01; error=41.0
# epoch=50; l_rate=0.01; error=43.0
# epoch=51; l_rate=0.01; error=34.0
# epoch=52; l_rate=0.01; error=36.0
# epoch=53; l_rate=0.01; error=28.0
# epoch=54; l_rate=0.01; error=34.0
# epoch=55; l_rate=0.01; error=42.0
# epoch=56; l_rate=0.01; error=36.0
# epoch=57; l_rate=0.01; error=28.0
# epoch=58; l_rate=0.01; error=28.0
# epoch=59; l_rate=0.01; error=28.0
# epoch=60; l_rate=0.01; error=24.0
# epoch=61; l_rate=0.01; error=28.0
# epoch=62; l_rate=0.01; error=28.0
# epoch=63; l_rate=0.01; error=34.0
# epoch=64; l_rate=0.01; error=39.0
# epoch=65; l_rate=0.01; error=32.0
# epoch=66; l_rate=0.01; error=28.0
# epoch=67; l_rate=0.01; error=41.0
# epoch=68; l_rate=0.01; error=34.0
# epoch=69; l_rate=0.01; error=40.0
# epoch=70; l_rate=0.01; error=30.0
# epoch=71; l_rate=0.01; error=37.0
# epoch=72; l_rate=0.01; error=26.0
# epoch=73; l_rate=0.01; error=25.0
# epoch=74; l_rate=0.01; error=27.0
# epoch=75; l_rate=0.01; error=28.0
# epoch=76; l_rate=0.01; error=36.0
# epoch=77; l_rate=0.01; error=32.0
# epoch=78; l_rate=0.01; error=31.0
# epoch=79; l_rate=0.01; error=22.0
# epoch=80; l_rate=0.01; error=26.0
# epoch=81; l_rate=0.01; error=21.0
# epoch=82; l_rate=0.01; error=33.0
# epoch=83; l_rate=0.01; error=28.0
# epoch=84; l_rate=0.01; error=36.0
# epoch=85; l_rate=0.01; error=30.0
# epoch=86; l_rate=0.01; error=32.0
# epoch=87; l_rate=0.01; error=35.0
# epoch=88; l_rate=0.01; error=35.0
# epoch=89; l_rate=0.01; error=26.0
# epoch=90; l_rate=0.01; error=34.0
# epoch=91; l_rate=0.01; error=31.0
# epoch=92; l_rate=0.01; error=32.0
# epoch=93; l_rate=0.01; error=33.0
# epoch=94; l_rate=0.01; error=32.0
# epoch=95; l_rate=0.01; error=21.0
# epoch=96; l_rate=0.01; error=28.0
# epoch=97; l_rate=0.01; error=30.0
# epoch=98; l_rate=0.01; error=30.0
# epoch=99; l_rate=0.01; error=28.0
# epoch=100; l_rate=0.01; error=30.0
# epoch=101; l_rate=0.01; error=34.0
# epoch=102; l_rate=0.01; error=34.0
# epoch=103; l_rate=0.01; error=30.0
# epoch=104; l_rate=0.01; error=32.0
# epoch=105; l_rate=0.01; error=28.0
# epoch=106; l_rate=0.01; error=26.0
# epoch=107; l_rate=0.01; error=25.0
# epoch=108; l_rate=0.01; error=26.0
# epoch=109; l_rate=0.01; error=28.0
# epoch=110; l_rate=0.01; error=30.0
# epoch=111; l_rate=0.01; error=22.0
# epoch=112; l_rate=0.01; error=23.0
# epoch=113; l_rate=0.01; error=24.0
# epoch=114; l_rate=0.01; error=26.0
# epoch=115; l_rate=0.01; error=30.0
# epoch=116; l_rate=0.01; error=26.0
# epoch=117; l_rate=0.01; error=28.0
# epoch=118; l_rate=0.01; error=32.0
# epoch=119; l_rate=0.01; error=28.0
# epoch=120; l_rate=0.01; error=20.0
# epoch=121; l_rate=0.01; error=36.0
# epoch=122; l_rate=0.01; error=32.0
# epoch=123; l_rate=0.01; error=26.0
# epoch=124; l_rate=0.01; error=32.0
# epoch=125; l_rate=0.01; error=28.0
# epoch=126; l_rate=0.01; error=28.0
# epoch=127; l_rate=0.01; error=32.0
# epoch=128; l_rate=0.01; error=34.0
# epoch=129; l_rate=0.01; error=32.0
# epoch=130; l_rate=0.01; error=20.0
# epoch=131; l_rate=0.01; error=24.0
# epoch=132; l_rate=0.01; error=24.0
# epoch=133; l_rate=0.01; error=25.0
# epoch=134; l_rate=0.01; error=28.0
# epoch=135; l_rate=0.01; error=22.0
# epoch=136; l_rate=0.01; error=26.0
# epoch=137; l_rate=0.01; error=36.0
# epoch=138; l_rate=0.01; error=28.0
# epoch=139; l_rate=0.01; error=28.0
# epoch=140; l_rate=0.01; error=28.0
# epoch=141; l_rate=0.01; error=28.0
# epoch=142; l_rate=0.01; error=16.0
# epoch=143; l_rate=0.01; error=24.0
# epoch=144; l_rate=0.01; error=27.0
# epoch=145; l_rate=0.01; error=19.0
# epoch=146; l_rate=0.01; error=30.0
# epoch=147; l_rate=0.01; error=26.0
# epoch=148; l_rate=0.01; error=32.0
# epoch=149; l_rate=0.01; error=20.0
# epoch=150; l_rate=0.01; error=27.0
# epoch=151; l_rate=0.01; error=22.0
# epoch=152; l_rate=0.01; error=22.0
# epoch=153; l_rate=0.01; error=22.0
# epoch=154; l_rate=0.01; error=28.0
# epoch=155; l_rate=0.01; error=22.0
# epoch=156; l_rate=0.01; error=18.0
# epoch=157; l_rate=0.01; error=28.0
# epoch=158; l_rate=0.01; error=28.0
# epoch=159; l_rate=0.01; error=24.0
# epoch=160; l_rate=0.01; error=26.0
# epoch=161; l_rate=0.01; error=28.0
# epoch=162; l_rate=0.01; error=24.0
# epoch=163; l_rate=0.01; error=24.0
# epoch=164; l_rate=0.01; error=26.0
# epoch=165; l_rate=0.01; error=20.0
# epoch=166; l_rate=0.01; error=26.0
# epoch=167; l_rate=0.01; error=25.0
# epoch=168; l_rate=0.01; error=20.0
# epoch=169; l_rate=0.01; error=26.0
# epoch=170; l_rate=0.01; error=26.0
# epoch=171; l_rate=0.01; error=29.0
# epoch=172; l_rate=0.01; error=17.0
# epoch=173; l_rate=0.01; error=26.0
# epoch=174; l_rate=0.01; error=22.0
# epoch=175; l_rate=0.01; error=30.0
# epoch=176; l_rate=0.01; error=26.0
# epoch=177; l_rate=0.01; error=26.0
# epoch=178; l_rate=0.01; error=24.0
# epoch=179; l_rate=0.01; error=22.0
# epoch=180; l_rate=0.01; error=24.0
# epoch=181; l_rate=0.01; error=22.0
# epoch=182; l_rate=0.01; error=20.0
# epoch=183; l_rate=0.01; error=26.0
# epoch=184; l_rate=0.01; error=18.0
# epoch=185; l_rate=0.01; error=23.0
# epoch=186; l_rate=0.01; error=22.0
# epoch=187; l_rate=0.01; error=24.0
# epoch=188; l_rate=0.01; error=20.0
# epoch=189; l_rate=0.01; error=24.0
# epoch=190; l_rate=0.01; error=24.0
# epoch=191; l_rate=0.01; error=28.0
# epoch=192; l_rate=0.01; error=24.0
# epoch=193; l_rate=0.01; error=22.0
# epoch=194; l_rate=0.01; error=20.0
# epoch=195; l_rate=0.01; error=24.0
# epoch=196; l_rate=0.01; error=24.0
# epoch=197; l_rate=0.01; error=29.0
# epoch=198; l_rate=0.01; error=24.0
# epoch=199; l_rate=0.01; error=22.0
# epoch=200; l_rate=0.01; error=22.0
# epoch=201; l_rate=0.01; error=28.0
# epoch=202; l_rate=0.01; error=20.0
# epoch=203; l_rate=0.01; error=24.0
# epoch=204; l_rate=0.01; error=23.0
# epoch=205; l_rate=0.01; error=22.0
# epoch=206; l_rate=0.01; error=14.0
# epoch=207; l_rate=0.01; error=26.0
# epoch=208; l_rate=0.01; error=26.0
# epoch=209; l_rate=0.01; error=20.0
# epoch=210; l_rate=0.01; error=22.0
# epoch=211; l_rate=0.01; error=20.0
# epoch=212; l_rate=0.01; error=20.0
# epoch=213; l_rate=0.01; error=26.0
# epoch=214; l_rate=0.01; error=22.0
# epoch=215; l_rate=0.01; error=22.0
# epoch=216; l_rate=0.01; error=20.0
# epoch=217; l_rate=0.01; error=24.0
# epoch=218; l_rate=0.01; error=22.0
# epoch=219; l_rate=0.01; error=24.0
# epoch=220; l_rate=0.01; error=18.0
# epoch=221; l_rate=0.01; error=18.0
# epoch=222; l_rate=0.01; error=22.0
# epoch=223; l_rate=0.01; error=22.0
# epoch=224; l_rate=0.01; error=22.0
# epoch=225; l_rate=0.01; error=24.0
# epoch=226; l_rate=0.01; error=20.0
# epoch=227; l_rate=0.01; error=22.0
# epoch=228; l_rate=0.01; error=18.0
# epoch=229; l_rate=0.01; error=24.0
# epoch=230; l_rate=0.01; error=22.0
# epoch=231; l_rate=0.01; error=22.0
# epoch=232; l_rate=0.01; error=24.0
# epoch=233; l_rate=0.01; error=18.0
# epoch=234; l_rate=0.01; error=22.0
# epoch=235; l_rate=0.01; error=22.0
# epoch=236; l_rate=0.01; error=22.0
# epoch=237; l_rate=0.01; error=21.0
# epoch=238; l_rate=0.01; error=18.0
# epoch=239; l_rate=0.01; error=26.0
# epoch=240; l_rate=0.01; error=20.0
# epoch=241; l_rate=0.01; error=20.0
# epoch=242; l_rate=0.01; error=22.0
# epoch=243; l_rate=0.01; error=22.0
# epoch=244; l_rate=0.01; error=21.0
# epoch=245; l_rate=0.01; error=21.0
# epoch=246; l_rate=0.01; error=20.0
# epoch=247; l_rate=0.01; error=20.0
# epoch=248; l_rate=0.01; error=23.0
# epoch=249; l_rate=0.01; error=18.0
# epoch=250; l_rate=0.01; error=23.0
# epoch=251; l_rate=0.01; error=23.0
# epoch=252; l_rate=0.01; error=22.0
# epoch=253; l_rate=0.01; error=17.0
# epoch=254; l_rate=0.01; error=20.0
# epoch=255; l_rate=0.01; error=24.0
# epoch=256; l_rate=0.01; error=20.0
# epoch=257; l_rate=0.01; error=14.0
# epoch=258; l_rate=0.01; error=24.0
# epoch=259; l_rate=0.01; error=18.0
# epoch=260; l_rate=0.01; error=20.0
# epoch=261; l_rate=0.01; error=20.0
# epoch=262; l_rate=0.01; error=16.0
# epoch=263; l_rate=0.01; error=20.0
# epoch=264; l_rate=0.01; error=18.0
# epoch=265; l_rate=0.01; error=18.0
# epoch=266; l_rate=0.01; error=18.0
# epoch=267; l_rate=0.01; error=16.0
# epoch=268; l_rate=0.01; error=16.0
# epoch=269; l_rate=0.01; error=21.0
# epoch=270; l_rate=0.01; error=20.0
# epoch=271; l_rate=0.01; error=20.0
# epoch=272; l_rate=0.01; error=15.0
# epoch=273; l_rate=0.01; error=16.0
# epoch=274; l_rate=0.01; error=18.0
# epoch=275; l_rate=0.01; error=18.0
# epoch=276; l_rate=0.01; error=16.0
# epoch=277; l_rate=0.01; error=24.0
# epoch=278; l_rate=0.01; error=18.0
# epoch=279; l_rate=0.01; error=20.0
# epoch=280; l_rate=0.01; error=16.0
# epoch=281; l_rate=0.01; error=22.0
# epoch=282; l_rate=0.01; error=24.0
# epoch=283; l_rate=0.01; error=22.0
# epoch=284; l_rate=0.01; error=18.0
# epoch=285; l_rate=0.01; error=17.0
# epoch=286; l_rate=0.01; error=20.0
# epoch=287; l_rate=0.01; error=22.0
# epoch=288; l_rate=0.01; error=18.0
# epoch=289; l_rate=0.01; error=18.0
# epoch=290; l_rate=0.01; error=22.0
# epoch=291; l_rate=0.01; error=24.0
# epoch=292; l_rate=0.01; error=22.0
# epoch=293; l_rate=0.01; error=20.0
# epoch=294; l_rate=0.01; error=17.0
# epoch=295; l_rate=0.01; error=22.0
# epoch=296; l_rate=0.01; error=14.0
# epoch=297; l_rate=0.01; error=18.0
# epoch=298; l_rate=0.01; error=18.0
# epoch=299; l_rate=0.01; error=16.0
# epoch=300; l_rate=0.01; error=18.0
# epoch=301; l_rate=0.01; error=18.0
# epoch=302; l_rate=0.01; error=18.0
# epoch=303; l_rate=0.01; error=22.0
# epoch=304; l_rate=0.01; error=16.0
# epoch=305; l_rate=0.01; error=16.0
# epoch=306; l_rate=0.01; error=22.0
# epoch=307; l_rate=0.01; error=22.0
# epoch=308; l_rate=0.01; error=28.0
# epoch=309; l_rate=0.01; error=24.0
# epoch=310; l_rate=0.01; error=24.0
# epoch=311; l_rate=0.01; error=18.0
# epoch=312; l_rate=0.01; error=21.0
# epoch=313; l_rate=0.01; error=18.0
# epoch=314; l_rate=0.01; error=16.0
# epoch=315; l_rate=0.01; error=18.0
# epoch=316; l_rate=0.01; error=18.0
# epoch=317; l_rate=0.01; error=16.0
# epoch=318; l_rate=0.01; error=18.0
# epoch=319; l_rate=0.01; error=18.0
# epoch=320; l_rate=0.01; error=20.0
# epoch=321; l_rate=0.01; error=14.0
# epoch=322; l_rate=0.01; error=18.0
# epoch=323; l_rate=0.01; error=14.0
# epoch=324; l_rate=0.01; error=16.0
# epoch=325; l_rate=0.01; error=23.0
# epoch=326; l_rate=0.01; error=22.0
# epoch=327; l_rate=0.01; error=16.0
# epoch=328; l_rate=0.01; error=15.0
# epoch=329; l_rate=0.01; error=18.0
# epoch=330; l_rate=0.01; error=18.0
# epoch=331; l_rate=0.01; error=18.0
# epoch=332; l_rate=0.01; error=16.0
# epoch=333; l_rate=0.01; error=22.0
# epoch=334; l_rate=0.01; error=20.0
# epoch=335; l_rate=0.01; error=19.0
# epoch=336; l_rate=0.01; error=12.0
# epoch=337; l_rate=0.01; error=20.0
# epoch=338; l_rate=0.01; error=20.0
# epoch=339; l_rate=0.01; error=18.0
# epoch=340; l_rate=0.01; error=16.0
# epoch=341; l_rate=0.01; error=22.0
# epoch=342; l_rate=0.01; error=20.0
# epoch=343; l_rate=0.01; error=28.0
# epoch=344; l_rate=0.01; error=20.0
# epoch=345; l_rate=0.01; error=18.0
# epoch=346; l_rate=0.01; error=17.0
# epoch=347; l_rate=0.01; error=14.0
# epoch=348; l_rate=0.01; error=14.0
# epoch=349; l_rate=0.01; error=16.0
# epoch=350; l_rate=0.01; error=26.0
# epoch=351; l_rate=0.01; error=16.0
# epoch=352; l_rate=0.01; error=20.0
# epoch=353; l_rate=0.01; error=22.0
# epoch=354; l_rate=0.01; error=25.0
# epoch=355; l_rate=0.01; error=14.0
# epoch=356; l_rate=0.01; error=18.0
# epoch=357; l_rate=0.01; error=18.0
# epoch=358; l_rate=0.01; error=16.0
# epoch=359; l_rate=0.01; error=21.0
# epoch=360; l_rate=0.01; error=16.0
# epoch=361; l_rate=0.01; error=24.0
# epoch=362; l_rate=0.01; error=20.0
# epoch=363; l_rate=0.01; error=14.0
# epoch=364; l_rate=0.01; error=12.0
# epoch=365; l_rate=0.01; error=26.0
# epoch=366; l_rate=0.01; error=22.0
# epoch=367; l_rate=0.01; error=22.0
# epoch=368; l_rate=0.01; error=16.0
# epoch=369; l_rate=0.01; error=16.0
# epoch=370; l_rate=0.01; error=18.0
# epoch=371; l_rate=0.01; error=14.0
# epoch=372; l_rate=0.01; error=16.0
# epoch=373; l_rate=0.01; error=21.0
# epoch=374; l_rate=0.01; error=24.0
# epoch=375; l_rate=0.01; error=26.0
# epoch=376; l_rate=0.01; error=15.0
# epoch=377; l_rate=0.01; error=18.0
# epoch=378; l_rate=0.01; error=12.0
# epoch=379; l_rate=0.01; error=20.0
# epoch=380; l_rate=0.01; error=16.0
# epoch=381; l_rate=0.01; error=18.0
# epoch=382; l_rate=0.01; error=14.0
# epoch=383; l_rate=0.01; error=20.0
# epoch=384; l_rate=0.01; error=20.0
# epoch=385; l_rate=0.01; error=16.0
# epoch=386; l_rate=0.01; error=16.0
# epoch=387; l_rate=0.01; error=24.0
# epoch=388; l_rate=0.01; error=22.0
# epoch=389; l_rate=0.01; error=14.0
# epoch=390; l_rate=0.01; error=17.0
# epoch=391; l_rate=0.01; error=18.0
# epoch=392; l_rate=0.01; error=18.0
# epoch=393; l_rate=0.01; error=24.0
# epoch=394; l_rate=0.01; error=13.0
# epoch=395; l_rate=0.01; error=15.0
# epoch=396; l_rate=0.01; error=10.0
# epoch=397; l_rate=0.01; error=16.0
# epoch=398; l_rate=0.01; error=16.0
# epoch=399; l_rate=0.01; error=18.0
# epoch=400; l_rate=0.01; error=20.0
# epoch=401; l_rate=0.01; error=20.0
# epoch=402; l_rate=0.01; error=18.0
# epoch=403; l_rate=0.01; error=20.0
# epoch=404; l_rate=0.01; error=18.0
# epoch=405; l_rate=0.01; error=16.0
# epoch=406; l_rate=0.01; error=20.0
# epoch=407; l_rate=0.01; error=23.0
# epoch=408; l_rate=0.01; error=20.0
# epoch=409; l_rate=0.01; error=16.0
# epoch=410; l_rate=0.01; error=16.0
# epoch=411; l_rate=0.01; error=18.0
# epoch=412; l_rate=0.01; error=18.0
# epoch=413; l_rate=0.01; error=20.0
# epoch=414; l_rate=0.01; error=14.0
# epoch=415; l_rate=0.01; error=14.0
# epoch=416; l_rate=0.01; error=20.0
# epoch=417; l_rate=0.01; error=24.0
# epoch=418; l_rate=0.01; error=20.0
# epoch=419; l_rate=0.01; error=14.0
# epoch=420; l_rate=0.01; error=14.0
# epoch=421; l_rate=0.01; error=15.0
# epoch=422; l_rate=0.01; error=18.0
# epoch=423; l_rate=0.01; error=18.0
# epoch=424; l_rate=0.01; error=12.0
# epoch=425; l_rate=0.01; error=17.0
# epoch=426; l_rate=0.01; error=19.0
# epoch=427; l_rate=0.01; error=13.0
# epoch=428; l_rate=0.01; error=14.0
# epoch=429; l_rate=0.01; error=18.0
# epoch=430; l_rate=0.01; error=18.0
# epoch=431; l_rate=0.01; error=17.0
# epoch=432; l_rate=0.01; error=16.0
# epoch=433; l_rate=0.01; error=14.0
# epoch=434; l_rate=0.01; error=16.0
# epoch=435; l_rate=0.01; error=19.0
# epoch=436; l_rate=0.01; error=21.0
# epoch=437; l_rate=0.01; error=15.0
# epoch=438; l_rate=0.01; error=20.0
# epoch=439; l_rate=0.01; error=18.0
# epoch=440; l_rate=0.01; error=16.0
# epoch=441; l_rate=0.01; error=20.0
# epoch=442; l_rate=0.01; error=12.0
# epoch=443; l_rate=0.01; error=22.0
# epoch=444; l_rate=0.01; error=14.0
# epoch=445; l_rate=0.01; error=20.0
# epoch=446; l_rate=0.01; error=17.0
# epoch=447; l_rate=0.01; error=18.0
# epoch=448; l_rate=0.01; error=23.0
# epoch=449; l_rate=0.01; error=10.0
# epoch=450; l_rate=0.01; error=16.0
# epoch=451; l_rate=0.01; error=14.0
# epoch=452; l_rate=0.01; error=18.0
# epoch=453; l_rate=0.01; error=20.0
# epoch=454; l_rate=0.01; error=16.0
# epoch=455; l_rate=0.01; error=12.0
# epoch=456; l_rate=0.01; error=12.0
# epoch=457; l_rate=0.01; error=17.0
# epoch=458; l_rate=0.01; error=12.0
# epoch=459; l_rate=0.01; error=14.0
# epoch=460; l_rate=0.01; error=12.0
# epoch=461; l_rate=0.01; error=16.0
# epoch=462; l_rate=0.01; error=20.0
# epoch=463; l_rate=0.01; error=18.0
# epoch=464; l_rate=0.01; error=14.0
# epoch=465; l_rate=0.01; error=12.0
# epoch=466; l_rate=0.01; error=18.0
# epoch=467; l_rate=0.01; error=14.0
# epoch=468; l_rate=0.01; error=17.0
# epoch=469; l_rate=0.01; error=20.0
# epoch=470; l_rate=0.01; error=18.0
# epoch=471; l_rate=0.01; error=20.0
# epoch=472; l_rate=0.01; error=12.0
# epoch=473; l_rate=0.01; error=14.0
# epoch=474; l_rate=0.01; error=12.0
# epoch=475; l_rate=0.01; error=16.0
# epoch=476; l_rate=0.01; error=22.0
# epoch=477; l_rate=0.01; error=14.0
# epoch=478; l_rate=0.01; error=14.0
# epoch=479; l_rate=0.01; error=16.0
# epoch=480; l_rate=0.01; error=23.0
# epoch=481; l_rate=0.01; error=16.0
# epoch=482; l_rate=0.01; error=13.0
# epoch=483; l_rate=0.01; error=21.0
# epoch=484; l_rate=0.01; error=18.0
# epoch=485; l_rate=0.01; error=12.0
# epoch=486; l_rate=0.01; error=12.0
# epoch=487; l_rate=0.01; error=16.0
# epoch=488; l_rate=0.01; error=21.0
# epoch=489; l_rate=0.01; error=22.0
# epoch=490; l_rate=0.01; error=22.0
# epoch=491; l_rate=0.01; error=20.0
# epoch=492; l_rate=0.01; error=14.0
# epoch=493; l_rate=0.01; error=14.0
# epoch=494; l_rate=0.01; error=14.0
# epoch=495; l_rate=0.01; error=20.0
# epoch=496; l_rate=0.01; error=21.0
# epoch=497; l_rate=0.01; error=18.0
# epoch=498; l_rate=0.01; error=16.0
# epoch=499; l_rate=0.01; error=14.0
# epoch=500; l_rate=0.01; error=14.0
# epoch=501; l_rate=0.01; error=14.0
# epoch=502; l_rate=0.01; error=18.0
# epoch=503; l_rate=0.01; error=16.0
# epoch=504; l_rate=0.01; error=21.0
# epoch=505; l_rate=0.01; error=20.0
# epoch=506; l_rate=0.01; error=16.0
# epoch=507; l_rate=0.01; error=22.0
# epoch=508; l_rate=0.01; error=23.0
# epoch=509; l_rate=0.01; error=21.0
# epoch=510; l_rate=0.01; error=14.0
# epoch=511; l_rate=0.01; error=12.0
# epoch=512; l_rate=0.01; error=12.0
# epoch=513; l_rate=0.01; error=13.0
# epoch=514; l_rate=0.01; error=15.0
# epoch=515; l_rate=0.01; error=16.0
# epoch=516; l_rate=0.01; error=16.0
# epoch=517; l_rate=0.01; error=20.0
# epoch=518; l_rate=0.01; error=16.0
# epoch=519; l_rate=0.01; error=16.0
# epoch=520; l_rate=0.01; error=10.0
# epoch=521; l_rate=0.01; error=19.0
# epoch=522; l_rate=0.01; error=18.0
# epoch=523; l_rate=0.01; error=22.0
# epoch=524; l_rate=0.01; error=18.0
# epoch=525; l_rate=0.01; error=13.0
# epoch=526; l_rate=0.01; error=15.0
# epoch=527; l_rate=0.01; error=14.0
# epoch=528; l_rate=0.01; error=20.0
# epoch=529; l_rate=0.01; error=24.0
# epoch=530; l_rate=0.01; error=18.0
# epoch=531; l_rate=0.01; error=24.0
# epoch=532; l_rate=0.01; error=12.0
# epoch=533; l_rate=0.01; error=22.0
# epoch=534; l_rate=0.01; error=12.0
# epoch=535; l_rate=0.01; error=16.0
# epoch=536; l_rate=0.01; error=11.0
# epoch=537; l_rate=0.01; error=18.0
# epoch=538; l_rate=0.01; error=14.0
# epoch=539; l_rate=0.01; error=21.0
# epoch=540; l_rate=0.01; error=12.0
# epoch=541; l_rate=0.01; error=14.0
# epoch=542; l_rate=0.01; error=15.0
# epoch=543; l_rate=0.01; error=20.0
# epoch=544; l_rate=0.01; error=12.0
# epoch=545; l_rate=0.01; error=14.0
# epoch=546; l_rate=0.01; error=14.0
# epoch=547; l_rate=0.01; error=16.0
# epoch=548; l_rate=0.01; error=20.0
# epoch=549; l_rate=0.01; error=16.0
# epoch=550; l_rate=0.01; error=18.0
# epoch=551; l_rate=0.01; error=22.0
# epoch=552; l_rate=0.01; error=14.0
# epoch=553; l_rate=0.01; error=12.0
# epoch=554; l_rate=0.01; error=18.0
# epoch=555; l_rate=0.01; error=14.0
# epoch=556; l_rate=0.01; error=16.0
# epoch=557; l_rate=0.01; error=13.0
# epoch=558; l_rate=0.01; error=19.0
# epoch=559; l_rate=0.01; error=16.0
# epoch=560; l_rate=0.01; error=20.0
# epoch=561; l_rate=0.01; error=16.0
# epoch=562; l_rate=0.01; error=15.0
# epoch=563; l_rate=0.01; error=18.0
# epoch=564; l_rate=0.01; error=17.0
# epoch=565; l_rate=0.01; error=15.0
# epoch=566; l_rate=0.01; error=12.0
# epoch=567; l_rate=0.01; error=14.0
# epoch=568; l_rate=0.01; error=14.0
# epoch=569; l_rate=0.01; error=17.0
# epoch=570; l_rate=0.01; error=16.0
# epoch=571; l_rate=0.01; error=19.0
# epoch=572; l_rate=0.01; error=16.0
# epoch=573; l_rate=0.01; error=18.0
# epoch=574; l_rate=0.01; error=16.0
# epoch=575; l_rate=0.01; error=14.0
# epoch=576; l_rate=0.01; error=18.0
# epoch=577; l_rate=0.01; error=19.0
# epoch=578; l_rate=0.01; error=21.0
# epoch=579; l_rate=0.01; error=16.0
# epoch=580; l_rate=0.01; error=18.0
# epoch=581; l_rate=0.01; error=16.0
# epoch=582; l_rate=0.01; error=18.0
# epoch=583; l_rate=0.01; error=17.0
# epoch=584; l_rate=0.01; error=16.0
# epoch=585; l_rate=0.01; error=19.0
# epoch=586; l_rate=0.01; error=14.0
# epoch=587; l_rate=0.01; error=20.0
# epoch=588; l_rate=0.01; error=20.0
# epoch=589; l_rate=0.01; error=19.0
# epoch=590; l_rate=0.01; error=12.0
# epoch=591; l_rate=0.01; error=15.0
# epoch=592; l_rate=0.01; error=14.0
# epoch=593; l_rate=0.01; error=16.0
# epoch=594; l_rate=0.01; error=14.0
# epoch=595; l_rate=0.01; error=10.0
# epoch=596; l_rate=0.01; error=12.0
# epoch=597; l_rate=0.01; error=14.0
# epoch=598; l_rate=0.01; error=16.0
# epoch=599; l_rate=0.01; error=18.0
# epoch=600; l_rate=0.01; error=16.0
# epoch=601; l_rate=0.01; error=14.0
# epoch=602; l_rate=0.01; error=14.0
# epoch=603; l_rate=0.01; error=22.0
# epoch=604; l_rate=0.01; error=12.0
# epoch=605; l_rate=0.01; error=16.0
# epoch=606; l_rate=0.01; error=16.0
# epoch=607; l_rate=0.01; error=20.0
# epoch=608; l_rate=0.01; error=11.0
# epoch=609; l_rate=0.01; error=17.0
# epoch=610; l_rate=0.01; error=18.0
# epoch=611; l_rate=0.01; error=20.0
# epoch=612; l_rate=0.01; error=13.0
# epoch=613; l_rate=0.01; error=12.0
# epoch=614; l_rate=0.01; error=26.0
# epoch=615; l_rate=0.01; error=13.0
# epoch=616; l_rate=0.01; error=22.0
# epoch=617; l_rate=0.01; error=15.0
# epoch=618; l_rate=0.01; error=13.0
# epoch=619; l_rate=0.01; error=18.0
# epoch=620; l_rate=0.01; error=15.0
# epoch=621; l_rate=0.01; error=12.0
# epoch=622; l_rate=0.01; error=12.0
# epoch=623; l_rate=0.01; error=14.0
# epoch=624; l_rate=0.01; error=17.0
# epoch=625; l_rate=0.01; error=16.0
# epoch=626; l_rate=0.01; error=17.0
# epoch=627; l_rate=0.01; error=18.0
# epoch=628; l_rate=0.01; error=14.0
# epoch=629; l_rate=0.01; error=15.0
# epoch=630; l_rate=0.01; error=17.0
# epoch=631; l_rate=0.01; error=11.0
# epoch=632; l_rate=0.01; error=12.0
# epoch=633; l_rate=0.01; error=14.0
# epoch=634; l_rate=0.01; error=16.0
# epoch=635; l_rate=0.01; error=12.0
# epoch=636; l_rate=0.01; error=20.0
# epoch=637; l_rate=0.01; error=16.0
# epoch=638; l_rate=0.01; error=17.0
# epoch=639; l_rate=0.01; error=15.0
# epoch=640; l_rate=0.01; error=14.0
# epoch=641; l_rate=0.01; error=10.0
# epoch=642; l_rate=0.01; error=18.0
# epoch=643; l_rate=0.01; error=15.0
# epoch=644; l_rate=0.01; error=16.0
# epoch=645; l_rate=0.01; error=16.0
# epoch=646; l_rate=0.01; error=16.0
# epoch=647; l_rate=0.01; error=18.0
# epoch=648; l_rate=0.01; error=18.0
# epoch=649; l_rate=0.01; error=18.0
# epoch=650; l_rate=0.01; error=16.0
# epoch=651; l_rate=0.01; error=17.0
# epoch=652; l_rate=0.01; error=19.0
# epoch=653; l_rate=0.01; error=19.0
# epoch=654; l_rate=0.01; error=13.0
# epoch=655; l_rate=0.01; error=16.0
# epoch=656; l_rate=0.01; error=18.0
# epoch=657; l_rate=0.01; error=15.0
# epoch=658; l_rate=0.01; error=16.0
# epoch=659; l_rate=0.01; error=18.0
# epoch=660; l_rate=0.01; error=14.0
# epoch=661; l_rate=0.01; error=14.0
# epoch=662; l_rate=0.01; error=15.0
# epoch=663; l_rate=0.01; error=16.0
# epoch=664; l_rate=0.01; error=19.0
# epoch=665; l_rate=0.01; error=14.0
# epoch=666; l_rate=0.01; error=14.0
# epoch=667; l_rate=0.01; error=11.0
# epoch=668; l_rate=0.01; error=16.0
# epoch=669; l_rate=0.01; error=18.0
# epoch=670; l_rate=0.01; error=14.0
# epoch=671; l_rate=0.01; error=17.0
# epoch=672; l_rate=0.01; error=11.0
# epoch=673; l_rate=0.01; error=8.0
# epoch=674; l_rate=0.01; error=16.0
# epoch=675; l_rate=0.01; error=16.0
# epoch=676; l_rate=0.01; error=14.0
# epoch=677; l_rate=0.01; error=9.0
# epoch=678; l_rate=0.01; error=18.0
# epoch=679; l_rate=0.01; error=16.0
# epoch=680; l_rate=0.01; error=17.0
# epoch=681; l_rate=0.01; error=16.0
# epoch=682; l_rate=0.01; error=15.0
# epoch=683; l_rate=0.01; error=14.0
# epoch=684; l_rate=0.01; error=16.0
# epoch=685; l_rate=0.01; error=15.0
# epoch=686; l_rate=0.01; error=18.0
# epoch=687; l_rate=0.01; error=18.0
# epoch=688; l_rate=0.01; error=18.0
# epoch=689; l_rate=0.01; error=18.0
# epoch=690; l_rate=0.01; error=13.0
# epoch=691; l_rate=0.01; error=12.0
# epoch=692; l_rate=0.01; error=17.0
# epoch=693; l_rate=0.01; error=15.0
# epoch=694; l_rate=0.01; error=14.0
# epoch=695; l_rate=0.01; error=16.0
# epoch=696; l_rate=0.01; error=8.0
# epoch=697; l_rate=0.01; error=18.0
# epoch=698; l_rate=0.01; error=14.0
# epoch=699; l_rate=0.01; error=14.0
# epoch=700; l_rate=0.01; error=14.0
# epoch=701; l_rate=0.01; error=20.0
# epoch=702; l_rate=0.01; error=19.0
# epoch=703; l_rate=0.01; error=14.0
# epoch=704; l_rate=0.01; error=13.0
# epoch=705; l_rate=0.01; error=10.0
# epoch=706; l_rate=0.01; error=18.0
# epoch=707; l_rate=0.01; error=18.0
# epoch=708; l_rate=0.01; error=15.0
# epoch=709; l_rate=0.01; error=19.0
# epoch=710; l_rate=0.01; error=18.0
# epoch=711; l_rate=0.01; error=17.0
# epoch=712; l_rate=0.01; error=15.0
# epoch=713; l_rate=0.01; error=16.0
# epoch=714; l_rate=0.01; error=12.0
# epoch=715; l_rate=0.01; error=16.0
# epoch=716; l_rate=0.01; error=18.0
# epoch=717; l_rate=0.01; error=12.0
# epoch=718; l_rate=0.01; error=14.0
# epoch=719; l_rate=0.01; error=16.0
# epoch=720; l_rate=0.01; error=11.0
# epoch=721; l_rate=0.01; error=14.0
# epoch=722; l_rate=0.01; error=14.0
# epoch=723; l_rate=0.01; error=12.0
# epoch=724; l_rate=0.01; error=14.0
# epoch=725; l_rate=0.01; error=16.0
# epoch=726; l_rate=0.01; error=14.0
# epoch=727; l_rate=0.01; error=14.0
# epoch=728; l_rate=0.01; error=14.0
# epoch=729; l_rate=0.01; error=19.0
# epoch=730; l_rate=0.01; error=14.0
# epoch=731; l_rate=0.01; error=12.0
# epoch=732; l_rate=0.01; error=12.0
# epoch=733; l_rate=0.01; error=12.0
# epoch=734; l_rate=0.01; error=14.0
# epoch=735; l_rate=0.01; error=14.0
# epoch=736; l_rate=0.01; error=14.0
# epoch=737; l_rate=0.01; error=10.0
# epoch=738; l_rate=0.01; error=17.0
# epoch=739; l_rate=0.01; error=15.0
# epoch=740; l_rate=0.01; error=16.0
# epoch=741; l_rate=0.01; error=14.0
# epoch=742; l_rate=0.01; error=14.0
# epoch=743; l_rate=0.01; error=19.0
# epoch=744; l_rate=0.01; error=8.0
# epoch=745; l_rate=0.01; error=14.0
# epoch=746; l_rate=0.01; error=18.0
# epoch=747; l_rate=0.01; error=14.0
# epoch=748; l_rate=0.01; error=18.0
# epoch=749; l_rate=0.01; error=20.0
# epoch=750; l_rate=0.01; error=20.0
# epoch=751; l_rate=0.01; error=8.0
# epoch=752; l_rate=0.01; error=19.0
# epoch=753; l_rate=0.01; error=14.0
# epoch=754; l_rate=0.01; error=20.0
# epoch=755; l_rate=0.01; error=9.0
# epoch=756; l_rate=0.01; error=15.0
# epoch=757; l_rate=0.01; error=15.0
# epoch=758; l_rate=0.01; error=18.0
# epoch=759; l_rate=0.01; error=14.0
# epoch=760; l_rate=0.01; error=14.0
# epoch=761; l_rate=0.01; error=13.0
# epoch=762; l_rate=0.01; error=15.0
# epoch=763; l_rate=0.01; error=12.0
# epoch=764; l_rate=0.01; error=12.0
# epoch=765; l_rate=0.01; error=16.0
# epoch=766; l_rate=0.01; error=16.0
# epoch=767; l_rate=0.01; error=16.0
# epoch=768; l_rate=0.01; error=19.0
# epoch=769; l_rate=0.01; error=14.0
# epoch=770; l_rate=0.01; error=12.0
# epoch=771; l_rate=0.01; error=15.0
# epoch=772; l_rate=0.01; error=16.0
# epoch=773; l_rate=0.01; error=18.0
# epoch=774; l_rate=0.01; error=10.0
# epoch=775; l_rate=0.01; error=18.0
# epoch=776; l_rate=0.01; error=14.0
# epoch=777; l_rate=0.01; error=16.0
# epoch=778; l_rate=0.01; error=15.0
# epoch=779; l_rate=0.01; error=14.0
# epoch=780; l_rate=0.01; error=13.0
# epoch=781; l_rate=0.01; error=16.0
# epoch=782; l_rate=0.01; error=18.0
# epoch=783; l_rate=0.01; error=16.0
# epoch=784; l_rate=0.01; error=14.0
# epoch=785; l_rate=0.01; error=16.0
# epoch=786; l_rate=0.01; error=12.0
# epoch=787; l_rate=0.01; error=18.0
# epoch=788; l_rate=0.01; error=8.0
# epoch=789; l_rate=0.01; error=19.0
# epoch=790; l_rate=0.01; error=10.0
# epoch=791; l_rate=0.01; error=16.0
# epoch=792; l_rate=0.01; error=14.0
# epoch=793; l_rate=0.01; error=14.0
# epoch=794; l_rate=0.01; error=15.0
# epoch=795; l_rate=0.01; error=16.0
# epoch=796; l_rate=0.01; error=18.0
# epoch=797; l_rate=0.01; error=12.0
# epoch=798; l_rate=0.01; error=18.0
# epoch=799; l_rate=0.01; error=18.0
# epoch=800; l_rate=0.01; error=13.0
# epoch=801; l_rate=0.01; error=14.0
# epoch=802; l_rate=0.01; error=18.0
# epoch=803; l_rate=0.01; error=13.0
# epoch=804; l_rate=0.01; error=14.0
# epoch=805; l_rate=0.01; error=14.0
# epoch=806; l_rate=0.01; error=10.0
# epoch=807; l_rate=0.01; error=14.0
# epoch=808; l_rate=0.01; error=17.0
# epoch=809; l_rate=0.01; error=11.0
# epoch=810; l_rate=0.01; error=10.0
# epoch=811; l_rate=0.01; error=16.0
# epoch=812; l_rate=0.01; error=14.0
# epoch=813; l_rate=0.01; error=18.0
# epoch=814; l_rate=0.01; error=18.0
# epoch=815; l_rate=0.01; error=10.0
# epoch=816; l_rate=0.01; error=11.0
# epoch=817; l_rate=0.01; error=16.0
# epoch=818; l_rate=0.01; error=14.0
# epoch=819; l_rate=0.01; error=11.0
# epoch=820; l_rate=0.01; error=18.0
# epoch=821; l_rate=0.01; error=18.0
# epoch=822; l_rate=0.01; error=16.0
# epoch=823; l_rate=0.01; error=15.0
# epoch=824; l_rate=0.01; error=16.0
# epoch=825; l_rate=0.01; error=18.0
# epoch=826; l_rate=0.01; error=18.0
# epoch=827; l_rate=0.01; error=16.0
# epoch=828; l_rate=0.01; error=16.0
# epoch=829; l_rate=0.01; error=15.0
# epoch=830; l_rate=0.01; error=20.0
# epoch=831; l_rate=0.01; error=18.0
# epoch=832; l_rate=0.01; error=12.0
# epoch=833; l_rate=0.01; error=18.0
# epoch=834; l_rate=0.01; error=14.0
# epoch=835; l_rate=0.01; error=22.0
# epoch=836; l_rate=0.01; error=22.0
# epoch=837; l_rate=0.01; error=16.0
# epoch=838; l_rate=0.01; error=10.0
# epoch=839; l_rate=0.01; error=14.0
# epoch=840; l_rate=0.01; error=16.0
# epoch=841; l_rate=0.01; error=14.0
# epoch=842; l_rate=0.01; error=16.0
# epoch=843; l_rate=0.01; error=19.0
# epoch=844; l_rate=0.01; error=10.0
# epoch=845; l_rate=0.01; error=12.0
# epoch=846; l_rate=0.01; error=20.0
# epoch=847; l_rate=0.01; error=13.0
# epoch=848; l_rate=0.01; error=14.0
# epoch=849; l_rate=0.01; error=18.0
# epoch=850; l_rate=0.01; error=11.0
# epoch=851; l_rate=0.01; error=16.0
# epoch=852; l_rate=0.01; error=18.0
# epoch=853; l_rate=0.01; error=6.0
# epoch=854; l_rate=0.01; error=8.0
# epoch=855; l_rate=0.01; error=8.0
# epoch=856; l_rate=0.01; error=14.0
# epoch=857; l_rate=0.01; error=12.0
# epoch=858; l_rate=0.01; error=7.0
# epoch=859; l_rate=0.01; error=12.0
# epoch=860; l_rate=0.01; error=14.0
# epoch=861; l_rate=0.01; error=18.0
# epoch=862; l_rate=0.01; error=10.0
# epoch=863; l_rate=0.01; error=14.0
# epoch=864; l_rate=0.01; error=9.0
# epoch=865; l_rate=0.01; error=13.0
# epoch=866; l_rate=0.01; error=16.0
# epoch=867; l_rate=0.01; error=14.0
# epoch=868; l_rate=0.01; error=13.0
# epoch=869; l_rate=0.01; error=14.0
# epoch=870; l_rate=0.01; error=20.0
# epoch=871; l_rate=0.01; error=9.0
# epoch=872; l_rate=0.01; error=8.0
# epoch=873; l_rate=0.01; error=9.0
# epoch=874; l_rate=0.01; error=16.0
# epoch=875; l_rate=0.01; error=12.0
# epoch=876; l_rate=0.01; error=14.0
# epoch=877; l_rate=0.01; error=11.0
# epoch=878; l_rate=0.01; error=16.0
# epoch=879; l_rate=0.01; error=20.0
# epoch=880; l_rate=0.01; error=15.0
# epoch=881; l_rate=0.01; error=14.0
# epoch=882; l_rate=0.01; error=16.0
# epoch=883; l_rate=0.01; error=9.0
# epoch=884; l_rate=0.01; error=9.0
# epoch=885; l_rate=0.01; error=16.0
# epoch=886; l_rate=0.01; error=20.0
# epoch=887; l_rate=0.01; error=12.0
# epoch=888; l_rate=0.01; error=14.0
# epoch=889; l_rate=0.01; error=14.0
# epoch=890; l_rate=0.01; error=22.0
# epoch=891; l_rate=0.01; error=10.0
# epoch=892; l_rate=0.01; error=10.0
# epoch=893; l_rate=0.01; error=20.0
# epoch=894; l_rate=0.01; error=6.0
# epoch=895; l_rate=0.01; error=16.0
# epoch=896; l_rate=0.01; error=16.0
# epoch=897; l_rate=0.01; error=10.0
# epoch=898; l_rate=0.01; error=12.0
# epoch=899; l_rate=0.01; error=8.0
# epoch=900; l_rate=0.01; error=17.0
# epoch=901; l_rate=0.01; error=13.0
# epoch=902; l_rate=0.01; error=6.0
# epoch=903; l_rate=0.01; error=12.0
# epoch=904; l_rate=0.01; error=6.0
# epoch=905; l_rate=0.01; error=14.0
# epoch=906; l_rate=0.01; error=14.0
# epoch=907; l_rate=0.01; error=14.0
# epoch=908; l_rate=0.01; error=12.0
# epoch=909; l_rate=0.01; error=13.0
# epoch=910; l_rate=0.01; error=10.0
# epoch=911; l_rate=0.01; error=7.0
# epoch=912; l_rate=0.01; error=15.0
# epoch=913; l_rate=0.01; error=11.0
# epoch=914; l_rate=0.01; error=18.0
# epoch=915; l_rate=0.01; error=14.0
# epoch=916; l_rate=0.01; error=12.0
# epoch=917; l_rate=0.01; error=18.0
# epoch=918; l_rate=0.01; error=10.0
# epoch=919; l_rate=0.01; error=16.0
# epoch=920; l_rate=0.01; error=10.0
# epoch=921; l_rate=0.01; error=14.0
# epoch=922; l_rate=0.01; error=12.0
# epoch=923; l_rate=0.01; error=6.0
# epoch=924; l_rate=0.01; error=10.0
# epoch=925; l_rate=0.01; error=16.0
# epoch=926; l_rate=0.01; error=12.0
# epoch=927; l_rate=0.01; error=18.0
# epoch=928; l_rate=0.01; error=14.0
# epoch=929; l_rate=0.01; error=18.0
# epoch=930; l_rate=0.01; error=20.0
# epoch=931; l_rate=0.01; error=14.0
# epoch=932; l_rate=0.01; error=10.0
# epoch=933; l_rate=0.01; error=14.0
# epoch=934; l_rate=0.01; error=12.0
# epoch=935; l_rate=0.01; error=10.0
# epoch=936; l_rate=0.01; error=10.0
# epoch=937; l_rate=0.01; error=10.0
# epoch=938; l_rate=0.01; error=12.0
# epoch=939; l_rate=0.01; error=10.0
# epoch=940; l_rate=0.01; error=13.0
# epoch=941; l_rate=0.01; error=14.0
# epoch=942; l_rate=0.01; error=20.0
# epoch=943; l_rate=0.01; error=10.0
# epoch=944; l_rate=0.01; error=12.0
# epoch=945; l_rate=0.01; error=10.0
# epoch=946; l_rate=0.01; error=16.0
# epoch=947; l_rate=0.01; error=18.0
# epoch=948; l_rate=0.01; error=13.0
# epoch=949; l_rate=0.01; error=16.0
# epoch=950; l_rate=0.01; error=9.0
# epoch=951; l_rate=0.01; error=18.0
# epoch=952; l_rate=0.01; error=8.0
# epoch=953; l_rate=0.01; error=16.0
# epoch=954; l_rate=0.01; error=18.0
# epoch=955; l_rate=0.01; error=16.0
# epoch=956; l_rate=0.01; error=4.0
# epoch=957; l_rate=0.01; error=16.0
# epoch=958; l_rate=0.01; error=10.0
# epoch=959; l_rate=0.01; error=6.0
# epoch=960; l_rate=0.01; error=16.0
# epoch=961; l_rate=0.01; error=10.0
# epoch=962; l_rate=0.01; error=11.0
# epoch=963; l_rate=0.01; error=14.0
# epoch=964; l_rate=0.01; error=8.0
# epoch=965; l_rate=0.01; error=10.0
# epoch=966; l_rate=0.01; error=18.0
# epoch=967; l_rate=0.01; error=10.0
# epoch=968; l_rate=0.01; error=6.0
# epoch=969; l_rate=0.01; error=16.0
# epoch=970; l_rate=0.01; error=10.0
# epoch=971; l_rate=0.01; error=12.0
# epoch=972; l_rate=0.01; error=12.0
# epoch=973; l_rate=0.01; error=8.0
# epoch=974; l_rate=0.01; error=10.0
# epoch=975; l_rate=0.01; error=12.0
# epoch=976; l_rate=0.01; error=16.0
# epoch=977; l_rate=0.01; error=12.0
# epoch=978; l_rate=0.01; error=14.0
# epoch=979; l_rate=0.01; error=10.0
# epoch=980; l_rate=0.01; error=12.0
# epoch=981; l_rate=0.01; error=14.0
# epoch=982; l_rate=0.01; error=6.0
# epoch=983; l_rate=0.01; error=10.0
# epoch=984; l_rate=0.01; error=8.0
# epoch=985; l_rate=0.01; error=14.0
# epoch=986; l_rate=0.01; error=14.0
# epoch=987; l_rate=0.01; error=8.0
# epoch=988; l_rate=0.01; error=12.0
# epoch=989; l_rate=0.01; error=14.0
# epoch=990; l_rate=0.01; error=10.0
# epoch=991; l_rate=0.01; error=12.0
# epoch=992; l_rate=0.01; error=14.0
# epoch=993; l_rate=0.01; error=12.0
# epoch=994; l_rate=0.01; error=13.0
# epoch=995; l_rate=0.01; error=8.0
# epoch=996; l_rate=0.01; error=8.0
# epoch=997; l_rate=0.01; error=18.0
# epoch=998; l_rate=0.01; error=11.0
# epoch=999; l_rate=0.01; error=16.0
# epoch=0; l_rate=0.01; error=76.0
# epoch=1; l_rate=0.01; error=57.0
# epoch=2; l_rate=0.01; error=56.0
# epoch=3; l_rate=0.01; error=53.0
# epoch=4; l_rate=0.01; error=49.0
# epoch=5; l_rate=0.01; error=52.0
# epoch=6; l_rate=0.01; error=50.0
# epoch=7; l_rate=0.01; error=49.0
# epoch=8; l_rate=0.01; error=45.0
# epoch=9; l_rate=0.01; error=42.0
# epoch=10; l_rate=0.01; error=42.0
# epoch=11; l_rate=0.01; error=40.0
# epoch=12; l_rate=0.01; error=45.0
# epoch=13; l_rate=0.01; error=43.0
# epoch=14; l_rate=0.01; error=40.0
# epoch=15; l_rate=0.01; error=46.0
# epoch=16; l_rate=0.01; error=36.0
# epoch=17; l_rate=0.01; error=40.0
# epoch=18; l_rate=0.01; error=45.0
# epoch=19; l_rate=0.01; error=32.0
# epoch=20; l_rate=0.01; error=40.0
# epoch=21; l_rate=0.01; error=38.0
# epoch=22; l_rate=0.01; error=36.0
# epoch=23; l_rate=0.01; error=34.0
# epoch=24; l_rate=0.01; error=38.0
# epoch=25; l_rate=0.01; error=32.0
# epoch=26; l_rate=0.01; error=38.0
# epoch=27; l_rate=0.01; error=38.0
# epoch=28; l_rate=0.01; error=38.0
# epoch=29; l_rate=0.01; error=40.0
# epoch=30; l_rate=0.01; error=38.0
# epoch=31; l_rate=0.01; error=42.0
# epoch=32; l_rate=0.01; error=38.0
# epoch=33; l_rate=0.01; error=30.0
# epoch=34; l_rate=0.01; error=36.0
# epoch=35; l_rate=0.01; error=43.0
# epoch=36; l_rate=0.01; error=38.0
# epoch=37; l_rate=0.01; error=36.0
# epoch=38; l_rate=0.01; error=32.0
# epoch=39; l_rate=0.01; error=36.0
# epoch=40; l_rate=0.01; error=39.0
# epoch=41; l_rate=0.01; error=36.0
# epoch=42; l_rate=0.01; error=36.0
# epoch=43; l_rate=0.01; error=38.0
# epoch=44; l_rate=0.01; error=36.0
# epoch=45; l_rate=0.01; error=36.0
# epoch=46; l_rate=0.01; error=30.0
# epoch=47; l_rate=0.01; error=36.0
# epoch=48; l_rate=0.01; error=34.0
# epoch=49; l_rate=0.01; error=30.0
# epoch=50; l_rate=0.01; error=31.0
# epoch=51; l_rate=0.01; error=33.0
# epoch=52; l_rate=0.01; error=30.0
# epoch=53; l_rate=0.01; error=37.0
# epoch=54; l_rate=0.01; error=27.0
# epoch=55; l_rate=0.01; error=35.0
# epoch=56; l_rate=0.01; error=30.0
# epoch=57; l_rate=0.01; error=28.0
# epoch=58; l_rate=0.01; error=32.0
# epoch=59; l_rate=0.01; error=28.0
# epoch=60; l_rate=0.01; error=30.0
# epoch=61; l_rate=0.01; error=32.0
# epoch=62; l_rate=0.01; error=32.0
# epoch=63; l_rate=0.01; error=29.0
# epoch=64; l_rate=0.01; error=34.0
# epoch=65; l_rate=0.01; error=33.0
# epoch=66; l_rate=0.01; error=30.0
# epoch=67; l_rate=0.01; error=36.0
# epoch=68; l_rate=0.01; error=34.0
# epoch=69; l_rate=0.01; error=32.0
# epoch=70; l_rate=0.01; error=36.0
# epoch=71; l_rate=0.01; error=37.0
# epoch=72; l_rate=0.01; error=34.0
# epoch=73; l_rate=0.01; error=30.0
# epoch=74; l_rate=0.01; error=28.0
# epoch=75; l_rate=0.01; error=31.0
# epoch=76; l_rate=0.01; error=34.0
# epoch=77; l_rate=0.01; error=32.0
# epoch=78; l_rate=0.01; error=32.0
# epoch=79; l_rate=0.01; error=32.0
# epoch=80; l_rate=0.01; error=32.0
# epoch=81; l_rate=0.01; error=28.0
# epoch=82; l_rate=0.01; error=36.0
# epoch=83; l_rate=0.01; error=27.0
# epoch=84; l_rate=0.01; error=28.0
# epoch=85; l_rate=0.01; error=32.0
# epoch=86; l_rate=0.01; error=34.0
# epoch=87; l_rate=0.01; error=26.0
# epoch=88; l_rate=0.01; error=36.0
# epoch=89; l_rate=0.01; error=27.0
# epoch=90; l_rate=0.01; error=30.0
# epoch=91; l_rate=0.01; error=30.0
# epoch=92; l_rate=0.01; error=32.0
# epoch=93; l_rate=0.01; error=26.0
# epoch=94; l_rate=0.01; error=32.0
# epoch=95; l_rate=0.01; error=33.0
# epoch=96; l_rate=0.01; error=34.0
# epoch=97; l_rate=0.01; error=30.0
# epoch=98; l_rate=0.01; error=28.0
# epoch=99; l_rate=0.01; error=35.0
# epoch=100; l_rate=0.01; error=32.0
# epoch=101; l_rate=0.01; error=28.0
# epoch=102; l_rate=0.01; error=27.0
# epoch=103; l_rate=0.01; error=29.0
# epoch=104; l_rate=0.01; error=30.0
# epoch=105; l_rate=0.01; error=28.0
# epoch=106; l_rate=0.01; error=32.0
# epoch=107; l_rate=0.01; error=28.0
# epoch=108; l_rate=0.01; error=26.0
# epoch=109; l_rate=0.01; error=26.0
# epoch=110; l_rate=0.01; error=28.0
# epoch=111; l_rate=0.01; error=28.0
# epoch=112; l_rate=0.01; error=32.0
# epoch=113; l_rate=0.01; error=23.0
# epoch=114; l_rate=0.01; error=31.0
# epoch=115; l_rate=0.01; error=25.0
# epoch=116; l_rate=0.01; error=37.0
# epoch=117; l_rate=0.01; error=35.0
# epoch=118; l_rate=0.01; error=28.0
# epoch=119; l_rate=0.01; error=26.0
# epoch=120; l_rate=0.01; error=28.0
# epoch=121; l_rate=0.01; error=32.0
# epoch=122; l_rate=0.01; error=25.0
# epoch=123; l_rate=0.01; error=30.0
# epoch=124; l_rate=0.01; error=34.0
# epoch=125; l_rate=0.01; error=26.0
# epoch=126; l_rate=0.01; error=28.0
# epoch=127; l_rate=0.01; error=29.0
# epoch=128; l_rate=0.01; error=36.0
# epoch=129; l_rate=0.01; error=30.0
# epoch=130; l_rate=0.01; error=24.0
# epoch=131; l_rate=0.01; error=37.0
# epoch=132; l_rate=0.01; error=32.0
# epoch=133; l_rate=0.01; error=34.0
# epoch=134; l_rate=0.01; error=32.0
# epoch=135; l_rate=0.01; error=32.0
# epoch=136; l_rate=0.01; error=28.0
# epoch=137; l_rate=0.01; error=30.0
# epoch=138; l_rate=0.01; error=24.0
# epoch=139; l_rate=0.01; error=28.0
# epoch=140; l_rate=0.01; error=34.0
# epoch=141; l_rate=0.01; error=31.0
# epoch=142; l_rate=0.01; error=22.0
# epoch=143; l_rate=0.01; error=26.0
# epoch=144; l_rate=0.01; error=24.0
# epoch=145; l_rate=0.01; error=24.0
# epoch=146; l_rate=0.01; error=25.0
# epoch=147; l_rate=0.01; error=30.0
# epoch=148; l_rate=0.01; error=32.0
# epoch=149; l_rate=0.01; error=28.0
# epoch=150; l_rate=0.01; error=28.0
# epoch=151; l_rate=0.01; error=27.0
# epoch=152; l_rate=0.01; error=33.0
# epoch=153; l_rate=0.01; error=22.0
# epoch=154; l_rate=0.01; error=22.0
# epoch=155; l_rate=0.01; error=24.0
# epoch=156; l_rate=0.01; error=28.0
# epoch=157; l_rate=0.01; error=29.0
# epoch=158; l_rate=0.01; error=33.0
# epoch=159; l_rate=0.01; error=20.0
# epoch=160; l_rate=0.01; error=24.0
# epoch=161; l_rate=0.01; error=22.0
# epoch=162; l_rate=0.01; error=23.0
# epoch=163; l_rate=0.01; error=28.0
# epoch=164; l_rate=0.01; error=23.0
# epoch=165; l_rate=0.01; error=30.0
# epoch=166; l_rate=0.01; error=24.0
# epoch=167; l_rate=0.01; error=18.0
# epoch=168; l_rate=0.01; error=24.0
# epoch=169; l_rate=0.01; error=18.0
# epoch=170; l_rate=0.01; error=28.0
# epoch=171; l_rate=0.01; error=27.0
# epoch=172; l_rate=0.01; error=27.0
# epoch=173; l_rate=0.01; error=25.0
# epoch=174; l_rate=0.01; error=16.0
# epoch=175; l_rate=0.01; error=21.0
# epoch=176; l_rate=0.01; error=22.0
# epoch=177; l_rate=0.01; error=18.0
# epoch=178; l_rate=0.01; error=24.0
# epoch=179; l_rate=0.01; error=24.0
# epoch=180; l_rate=0.01; error=24.0
# epoch=181; l_rate=0.01; error=24.0
# epoch=182; l_rate=0.01; error=20.0
# epoch=183; l_rate=0.01; error=25.0
# epoch=184; l_rate=0.01; error=23.0
# epoch=185; l_rate=0.01; error=20.0
# epoch=186; l_rate=0.01; error=20.0
# epoch=187; l_rate=0.01; error=21.0
# epoch=188; l_rate=0.01; error=31.0
# epoch=189; l_rate=0.01; error=24.0
# epoch=190; l_rate=0.01; error=24.0
# epoch=191; l_rate=0.01; error=20.0
# epoch=192; l_rate=0.01; error=24.0
# epoch=193; l_rate=0.01; error=30.0
# epoch=194; l_rate=0.01; error=22.0
# epoch=195; l_rate=0.01; error=24.0
# epoch=196; l_rate=0.01; error=20.0
# epoch=197; l_rate=0.01; error=24.0
# epoch=198; l_rate=0.01; error=22.0
# epoch=199; l_rate=0.01; error=32.0
# epoch=200; l_rate=0.01; error=24.0
# epoch=201; l_rate=0.01; error=20.0
# epoch=202; l_rate=0.01; error=24.0
# epoch=203; l_rate=0.01; error=23.0
# epoch=204; l_rate=0.01; error=21.0
# epoch=205; l_rate=0.01; error=24.0
# epoch=206; l_rate=0.01; error=20.0
# epoch=207; l_rate=0.01; error=24.0
# epoch=208; l_rate=0.01; error=22.0
# epoch=209; l_rate=0.01; error=26.0
# epoch=210; l_rate=0.01; error=26.0
# epoch=211; l_rate=0.01; error=27.0
# epoch=212; l_rate=0.01; error=18.0
# epoch=213; l_rate=0.01; error=24.0
# epoch=214; l_rate=0.01; error=30.0
# epoch=215; l_rate=0.01; error=20.0
# epoch=216; l_rate=0.01; error=22.0
# epoch=217; l_rate=0.01; error=23.0
# epoch=218; l_rate=0.01; error=25.0
# epoch=219; l_rate=0.01; error=30.0
# epoch=220; l_rate=0.01; error=20.0
# epoch=221; l_rate=0.01; error=18.0
# epoch=222; l_rate=0.01; error=28.0
# epoch=223; l_rate=0.01; error=20.0
# epoch=224; l_rate=0.01; error=16.0
# epoch=225; l_rate=0.01; error=29.0
# epoch=226; l_rate=0.01; error=22.0
# epoch=227; l_rate=0.01; error=16.0
# epoch=228; l_rate=0.01; error=18.0
# epoch=229; l_rate=0.01; error=24.0
# epoch=230; l_rate=0.01; error=20.0
# epoch=231; l_rate=0.01; error=22.0
# epoch=232; l_rate=0.01; error=31.0
# epoch=233; l_rate=0.01; error=26.0
# epoch=234; l_rate=0.01; error=24.0
# epoch=235; l_rate=0.01; error=22.0
# epoch=236; l_rate=0.01; error=26.0
# epoch=237; l_rate=0.01; error=30.0
# epoch=238; l_rate=0.01; error=20.0
# epoch=239; l_rate=0.01; error=16.0
# epoch=240; l_rate=0.01; error=20.0
# epoch=241; l_rate=0.01; error=18.0
# epoch=242; l_rate=0.01; error=26.0
# epoch=243; l_rate=0.01; error=22.0
# epoch=244; l_rate=0.01; error=18.0
# epoch=245; l_rate=0.01; error=22.0
# epoch=246; l_rate=0.01; error=22.0
# epoch=247; l_rate=0.01; error=24.0
# epoch=248; l_rate=0.01; error=20.0
# epoch=249; l_rate=0.01; error=24.0
# epoch=250; l_rate=0.01; error=26.0
# epoch=251; l_rate=0.01; error=20.0
# epoch=252; l_rate=0.01; error=20.0
# epoch=253; l_rate=0.01; error=18.0
# epoch=254; l_rate=0.01; error=22.0
# epoch=255; l_rate=0.01; error=20.0
# epoch=256; l_rate=0.01; error=26.0
# epoch=257; l_rate=0.01; error=22.0
# epoch=258; l_rate=0.01; error=26.0
# epoch=259; l_rate=0.01; error=18.0
# epoch=260; l_rate=0.01; error=20.0
# epoch=261; l_rate=0.01; error=20.0
# epoch=262; l_rate=0.01; error=22.0
# epoch=263; l_rate=0.01; error=22.0
# epoch=264; l_rate=0.01; error=18.0
# epoch=265; l_rate=0.01; error=22.0
# epoch=266; l_rate=0.01; error=20.0
# epoch=267; l_rate=0.01; error=25.0
# epoch=268; l_rate=0.01; error=22.0
# epoch=269; l_rate=0.01; error=22.0
# epoch=270; l_rate=0.01; error=24.0
# epoch=271; l_rate=0.01; error=20.0
# epoch=272; l_rate=0.01; error=16.0
# epoch=273; l_rate=0.01; error=16.0
# epoch=274; l_rate=0.01; error=20.0
# epoch=275; l_rate=0.01; error=22.0
# epoch=276; l_rate=0.01; error=28.0
# epoch=277; l_rate=0.01; error=20.0
# epoch=278; l_rate=0.01; error=24.0
# epoch=279; l_rate=0.01; error=24.0
# epoch=280; l_rate=0.01; error=28.0
# epoch=281; l_rate=0.01; error=22.0
# epoch=282; l_rate=0.01; error=20.0
# epoch=283; l_rate=0.01; error=22.0
# epoch=284; l_rate=0.01; error=18.0
# epoch=285; l_rate=0.01; error=26.0
# epoch=286; l_rate=0.01; error=20.0
# epoch=287; l_rate=0.01; error=20.0
# epoch=288; l_rate=0.01; error=21.0
# epoch=289; l_rate=0.01; error=20.0
# epoch=290; l_rate=0.01; error=24.0
# epoch=291; l_rate=0.01; error=28.0
# epoch=292; l_rate=0.01; error=18.0
# epoch=293; l_rate=0.01; error=22.0
# epoch=294; l_rate=0.01; error=22.0
# epoch=295; l_rate=0.01; error=24.0
# epoch=296; l_rate=0.01; error=16.0
# epoch=297; l_rate=0.01; error=20.0
# epoch=298; l_rate=0.01; error=22.0
# epoch=299; l_rate=0.01; error=18.0
# epoch=300; l_rate=0.01; error=22.0
# epoch=301; l_rate=0.01; error=24.0
# epoch=302; l_rate=0.01; error=22.0
# epoch=303; l_rate=0.01; error=18.0
# epoch=304; l_rate=0.01; error=20.0
# epoch=305; l_rate=0.01; error=16.0
# epoch=306; l_rate=0.01; error=18.0
# epoch=307; l_rate=0.01; error=20.0
# epoch=308; l_rate=0.01; error=26.0
# epoch=309; l_rate=0.01; error=18.0
# epoch=310; l_rate=0.01; error=18.0
# epoch=311; l_rate=0.01; error=24.0
# epoch=312; l_rate=0.01; error=28.0
# epoch=313; l_rate=0.01; error=24.0
# epoch=314; l_rate=0.01; error=16.0
# epoch=315; l_rate=0.01; error=26.0
# epoch=316; l_rate=0.01; error=20.0
# epoch=317; l_rate=0.01; error=18.0
# epoch=318; l_rate=0.01; error=16.0
# epoch=319; l_rate=0.01; error=23.0
# epoch=320; l_rate=0.01; error=22.0
# epoch=321; l_rate=0.01; error=20.0
# epoch=322; l_rate=0.01; error=20.0
# epoch=323; l_rate=0.01; error=18.0
# epoch=324; l_rate=0.01; error=22.0
# epoch=325; l_rate=0.01; error=24.0
# epoch=326; l_rate=0.01; error=18.0
# epoch=327; l_rate=0.01; error=22.0
# epoch=328; l_rate=0.01; error=16.0
# epoch=329; l_rate=0.01; error=20.0
# epoch=330; l_rate=0.01; error=20.0
# epoch=331; l_rate=0.01; error=20.0
# epoch=332; l_rate=0.01; error=22.0
# epoch=333; l_rate=0.01; error=24.0
# epoch=334; l_rate=0.01; error=20.0
# epoch=335; l_rate=0.01; error=22.0
# epoch=336; l_rate=0.01; error=18.0
# epoch=337; l_rate=0.01; error=21.0
# epoch=338; l_rate=0.01; error=23.0
# epoch=339; l_rate=0.01; error=20.0
# epoch=340; l_rate=0.01; error=22.0
# epoch=341; l_rate=0.01; error=20.0
# epoch=342; l_rate=0.01; error=18.0
# epoch=343; l_rate=0.01; error=22.0
# epoch=344; l_rate=0.01; error=20.0
# epoch=345; l_rate=0.01; error=20.0
# epoch=346; l_rate=0.01; error=18.0
# epoch=347; l_rate=0.01; error=26.0
# epoch=348; l_rate=0.01; error=26.0
# epoch=349; l_rate=0.01; error=21.0
# epoch=350; l_rate=0.01; error=20.0
# epoch=351; l_rate=0.01; error=20.0
# epoch=352; l_rate=0.01; error=18.0
# epoch=353; l_rate=0.01; error=18.0
# epoch=354; l_rate=0.01; error=16.0
# epoch=355; l_rate=0.01; error=22.0
# epoch=356; l_rate=0.01; error=18.0
# epoch=357; l_rate=0.01; error=26.0
# epoch=358; l_rate=0.01; error=16.0
# epoch=359; l_rate=0.01; error=22.0
# epoch=360; l_rate=0.01; error=20.0
# epoch=361; l_rate=0.01; error=24.0
# epoch=362; l_rate=0.01; error=16.0
# epoch=363; l_rate=0.01; error=20.0
# epoch=364; l_rate=0.01; error=18.0
# epoch=365; l_rate=0.01; error=26.0
# epoch=366; l_rate=0.01; error=20.0
# epoch=367; l_rate=0.01; error=20.0
# epoch=368; l_rate=0.01; error=18.0
# epoch=369; l_rate=0.01; error=22.0
# epoch=370; l_rate=0.01; error=20.0
# epoch=371; l_rate=0.01; error=16.0
# epoch=372; l_rate=0.01; error=24.0
# epoch=373; l_rate=0.01; error=20.0
# epoch=374; l_rate=0.01; error=16.0
# epoch=375; l_rate=0.01; error=14.0
# epoch=376; l_rate=0.01; error=16.0
# epoch=377; l_rate=0.01; error=24.0
# ...
# epoch=543; l_rate=0.01; error=14.0
# epoch=544; l_rate=0.01; error=16.0
# epoch=545; l_rate=0.01; error=15.0
# epoch=546; l_rate=0.01; error=14.0
# epoch=547; l_rate=0.01; error=7.0
# epoch=548; l_rate=0.01; error=11.0
# epoch=549; l_rate=0.01; error=12.0
# epoch=550; l_rate=0.01; error=18.0
# epoch=551; l_rate=0.01; error=12.0
# epoch=552; l_rate=0.01; error=18.0
# epoch=553; l_rate=0.01; error=17.0
# epoch=554; l_rate=0.01; error=19.0
# epoch=555; l_rate=0.01; error=20.0
# epoch=556; l_rate=0.01; error=21.0
# epoch=557; l_rate=0.01; error=11.0
# epoch=558; l_rate=0.01; error=6.0
# epoch=559; l_rate=0.01; error=6.0
# epoch=560; l_rate=0.01; error=14.0
# epoch=561; l_rate=0.01; error=16.0
# epoch=562; l_rate=0.01; error=17.0
# epoch=563; l_rate=0.01; error=11.0
# epoch=564; l_rate=0.01; error=14.0
# epoch=565; l_rate=0.01; error=14.0
# epoch=566; l_rate=0.01; error=10.0
# epoch=567; l_rate=0.01; error=6.0
# epoch=568; l_rate=0.01; error=18.0
# epoch=569; l_rate=0.01; error=12.0
# epoch=570; l_rate=0.01; error=14.0
# epoch=571; l_rate=0.01; error=8.0
# epoch=572; l_rate=0.01; error=14.0
# epoch=573; l_rate=0.01; error=8.0
# epoch=574; l_rate=0.01; error=6.0
# epoch=575; l_rate=0.01; error=14.0
# epoch=576; l_rate=0.01; error=16.0
# epoch=577; l_rate=0.01; error=14.0
# epoch=578; l_rate=0.01; error=10.0
# epoch=579; l_rate=0.01; error=10.0
# epoch=580; l_rate=0.01; error=16.0
# epoch=581; l_rate=0.01; error=14.0
# epoch=582; l_rate=0.01; error=8.0
# epoch=583; l_rate=0.01; error=10.0
# epoch=584; l_rate=0.01; error=8.0
# epoch=585; l_rate=0.01; error=6.0
# epoch=586; l_rate=0.01; error=8.0
# epoch=587; l_rate=0.01; error=14.0
# epoch=588; l_rate=0.01; error=16.0
# epoch=589; l_rate=0.01; error=16.0
# epoch=590; l_rate=0.01; error=20.0
# epoch=591; l_rate=0.01; error=16.0
# epoch=592; l_rate=0.01; error=14.0
# epoch=593; l_rate=0.01; error=18.0
# epoch=594; l_rate=0.01; error=14.0
# epoch=595; l_rate=0.01; error=14.0
# epoch=596; l_rate=0.01; error=14.0
# epoch=597; l_rate=0.01; error=12.0
# epoch=598; l_rate=0.01; error=12.0
# epoch=599; l_rate=0.01; error=10.0
# epoch=600; l_rate=0.01; error=8.0
# epoch=601; l_rate=0.01; error=20.0
# epoch=602; l_rate=0.01; error=6.0
# epoch=603; l_rate=0.01; error=8.0
# epoch=604; l_rate=0.01; error=12.0
# epoch=605; l_rate=0.01; error=8.0
# epoch=606; l_rate=0.01; error=16.0
# epoch=607; l_rate=0.01; error=14.0
# epoch=608; l_rate=0.01; error=16.0
# epoch=609; l_rate=0.01; error=14.0
# epoch=610; l_rate=0.01; error=12.0
# epoch=611; l_rate=0.01; error=16.0
# epoch=612; l_rate=0.01; error=8.0
# epoch=613; l_rate=0.01; error=6.0
# epoch=614; l_rate=0.01; error=20.0
# epoch=615; l_rate=0.01; error=12.0
# epoch=616; l_rate=0.01; error=10.0
# epoch=617; l_rate=0.01; error=10.0
# epoch=618; l_rate=0.01; error=8.0
# epoch=619; l_rate=0.01; error=16.0
# epoch=620; l_rate=0.01; error=14.0
# epoch=621; l_rate=0.01; error=12.0
# epoch=622; l_rate=0.01; error=10.0
# epoch=623; l_rate=0.01; error=8.0
# epoch=624; l_rate=0.01; error=8.0
# epoch=625; l_rate=0.01; error=14.0
# epoch=626; l_rate=0.01; error=4.0
# epoch=627; l_rate=0.01; error=20.0
# epoch=628; l_rate=0.01; error=12.0
# epoch=629; l_rate=0.01; error=12.0
# epoch=630; l_rate=0.01; error=16.0
# epoch=631; l_rate=0.01; error=8.0
# epoch=632; l_rate=0.01; error=12.0
# epoch=633; l_rate=0.01; error=10.0
# epoch=634; l_rate=0.01; error=12.0
# epoch=635; l_rate=0.01; error=8.0
# epoch=636; l_rate=0.01; error=22.0
# epoch=637; l_rate=0.01; error=14.0
# epoch=638; l_rate=0.01; error=8.0
# epoch=639; l_rate=0.01; error=16.0
# epoch=640; l_rate=0.01; error=14.0
# epoch=641; l_rate=0.01; error=14.0
# epoch=642; l_rate=0.01; error=10.0
# epoch=643; l_rate=0.01; error=18.0
# epoch=644; l_rate=0.01; error=14.0
# epoch=645; l_rate=0.01; error=4.0
# epoch=646; l_rate=0.01; error=14.0
# epoch=647; l_rate=0.01; error=14.0
# epoch=648; l_rate=0.01; error=14.0
# epoch=649; l_rate=0.01; error=22.0
# epoch=650; l_rate=0.01; error=8.0
# epoch=651; l_rate=0.01; error=14.0
# epoch=652; l_rate=0.01; error=18.0
# epoch=653; l_rate=0.01; error=17.0
# epoch=654; l_rate=0.01; error=12.0
# epoch=655; l_rate=0.01; error=16.0
# epoch=656; l_rate=0.01; error=12.0
# epoch=657; l_rate=0.01; error=18.0
# epoch=658; l_rate=0.01; error=4.0
# epoch=659; l_rate=0.01; error=10.0
# epoch=660; l_rate=0.01; error=6.0
# epoch=661; l_rate=0.01; error=20.0
# epoch=662; l_rate=0.01; error=20.0
# epoch=663; l_rate=0.01; error=14.0
# epoch=664; l_rate=0.01; error=16.0
# epoch=665; l_rate=0.01; error=14.0
# epoch=666; l_rate=0.01; error=18.0
# epoch=667; l_rate=0.01; error=20.0
# epoch=668; l_rate=0.01; error=12.0
# epoch=669; l_rate=0.01; error=14.0
# epoch=670; l_rate=0.01; error=8.0
# epoch=671; l_rate=0.01; error=14.0
# epoch=672; l_rate=0.01; error=14.0
# epoch=673; l_rate=0.01; error=16.0
# epoch=674; l_rate=0.01; error=14.0
# epoch=675; l_rate=0.01; error=12.0
# epoch=676; l_rate=0.01; error=10.0
# epoch=677; l_rate=0.01; error=18.0
# epoch=678; l_rate=0.01; error=10.0
# epoch=679; l_rate=0.01; error=8.0
# epoch=680; l_rate=0.01; error=18.0
# epoch=681; l_rate=0.01; error=16.0
# epoch=682; l_rate=0.01; error=18.0
# epoch=683; l_rate=0.01; error=6.0
# epoch=684; l_rate=0.01; error=6.0
# epoch=685; l_rate=0.01; error=7.0
# epoch=686; l_rate=0.01; error=13.0
# epoch=687; l_rate=0.01; error=19.0
# epoch=688; l_rate=0.01; error=15.0
# epoch=689; l_rate=0.01; error=5.0
# epoch=690; l_rate=0.01; error=15.0
# epoch=691; l_rate=0.01; error=16.0
# epoch=692; l_rate=0.01; error=8.0
# epoch=693; l_rate=0.01; error=18.0
# epoch=694; l_rate=0.01; error=14.0
# epoch=695; l_rate=0.01; error=12.0
# epoch=696; l_rate=0.01; error=20.0
# epoch=697; l_rate=0.01; error=12.0
# epoch=698; l_rate=0.01; error=20.0
# epoch=699; l_rate=0.01; error=12.0
# epoch=700; l_rate=0.01; error=17.0
# epoch=701; l_rate=0.01; error=16.0
# epoch=702; l_rate=0.01; error=8.0
# epoch=703; l_rate=0.01; error=12.0
# epoch=704; l_rate=0.01; error=8.0
# epoch=705; l_rate=0.01; error=12.0
# epoch=706; l_rate=0.01; error=14.0
# epoch=707; l_rate=0.01; error=6.0
# epoch=708; l_rate=0.01; error=14.0
# epoch=709; l_rate=0.01; error=19.0
# epoch=710; l_rate=0.01; error=11.0
# epoch=711; l_rate=0.01; error=14.0
# epoch=712; l_rate=0.01; error=10.0
# epoch=713; l_rate=0.01; error=6.0
# epoch=714; l_rate=0.01; error=14.0
# epoch=715; l_rate=0.01; error=6.0
# epoch=716; l_rate=0.01; error=14.0
# epoch=717; l_rate=0.01; error=12.0
# epoch=718; l_rate=0.01; error=15.0
# epoch=719; l_rate=0.01; error=5.0
# epoch=720; l_rate=0.01; error=10.0
# epoch=721; l_rate=0.01; error=18.0
# epoch=722; l_rate=0.01; error=12.0
# epoch=723; l_rate=0.01; error=18.0
# epoch=724; l_rate=0.01; error=16.0
# epoch=725; l_rate=0.01; error=9.0
# epoch=726; l_rate=0.01; error=11.0
# epoch=727; l_rate=0.01; error=8.0
# epoch=728; l_rate=0.01; error=12.0
# epoch=729; l_rate=0.01; error=12.0
# epoch=730; l_rate=0.01; error=14.0
# epoch=731; l_rate=0.01; error=16.0
# epoch=732; l_rate=0.01; error=17.0
# epoch=733; l_rate=0.01; error=9.0
# epoch=734; l_rate=0.01; error=10.0
# epoch=735; l_rate=0.01; error=12.0
# epoch=736; l_rate=0.01; error=8.0
# epoch=737; l_rate=0.01; error=16.0
# epoch=738; l_rate=0.01; error=14.0
# epoch=739; l_rate=0.01; error=14.0
# epoch=740; l_rate=0.01; error=12.0
# epoch=741; l_rate=0.01; error=16.0
# epoch=742; l_rate=0.01; error=12.0
# epoch=743; l_rate=0.01; error=17.0
# epoch=744; l_rate=0.01; error=17.0
# epoch=745; l_rate=0.01; error=3.0
# epoch=746; l_rate=0.01; error=4.0
# epoch=747; l_rate=0.01; error=10.0
# epoch=748; l_rate=0.01; error=12.0
# epoch=749; l_rate=0.01; error=7.0
# epoch=750; l_rate=0.01; error=12.0
# epoch=751; l_rate=0.01; error=14.0
# epoch=752; l_rate=0.01; error=12.0
# epoch=753; l_rate=0.01; error=12.0
# epoch=754; l_rate=0.01; error=10.0
# epoch=755; l_rate=0.01; error=8.0
# epoch=756; l_rate=0.01; error=11.0
# epoch=757; l_rate=0.01; error=13.0
# epoch=758; l_rate=0.01; error=12.0
# epoch=759; l_rate=0.01; error=14.0
# epoch=760; l_rate=0.01; error=12.0
# epoch=761; l_rate=0.01; error=8.0
# epoch=762; l_rate=0.01; error=12.0
# epoch=763; l_rate=0.01; error=3.0
# epoch=764; l_rate=0.01; error=15.0
# epoch=765; l_rate=0.01; error=20.0
# epoch=766; l_rate=0.01; error=12.0
# epoch=767; l_rate=0.01; error=8.0
# epoch=768; l_rate=0.01; error=12.0
# epoch=769; l_rate=0.01; error=9.0
# epoch=770; l_rate=0.01; error=8.0
# epoch=771; l_rate=0.01; error=10.0
# epoch=772; l_rate=0.01; error=6.0
# epoch=773; l_rate=0.01; error=10.0
# epoch=774; l_rate=0.01; error=11.0
# epoch=775; l_rate=0.01; error=5.0
# epoch=776; l_rate=0.01; error=13.0
# epoch=777; l_rate=0.01; error=10.0
# epoch=778; l_rate=0.01; error=14.0
# epoch=779; l_rate=0.01; error=8.0
# epoch=780; l_rate=0.01; error=12.0
# epoch=781; l_rate=0.01; error=18.0
# epoch=782; l_rate=0.01; error=12.0
# epoch=783; l_rate=0.01; error=18.0
# epoch=784; l_rate=0.01; error=15.0
# epoch=785; l_rate=0.01; error=15.0
# epoch=786; l_rate=0.01; error=12.0
# epoch=787; l_rate=0.01; error=10.0
# epoch=788; l_rate=0.01; error=10.0
# epoch=789; l_rate=0.01; error=14.0
# epoch=790; l_rate=0.01; error=14.0
# epoch=791; l_rate=0.01; error=18.0
# epoch=792; l_rate=0.01; error=14.0
# epoch=793; l_rate=0.01; error=12.0
# epoch=794; l_rate=0.01; error=12.0
# epoch=795; l_rate=0.01; error=12.0
# epoch=796; l_rate=0.01; error=17.0
# epoch=797; l_rate=0.01; error=14.0
# epoch=798; l_rate=0.01; error=11.0
# epoch=799; l_rate=0.01; error=12.0
# epoch=800; l_rate=0.01; error=12.0
# epoch=801; l_rate=0.01; error=12.0
# epoch=802; l_rate=0.01; error=16.0
# epoch=803; l_rate=0.01; error=16.0
# epoch=804; l_rate=0.01; error=6.0
# epoch=805; l_rate=0.01; error=8.0
# epoch=806; l_rate=0.01; error=12.0
# epoch=807; l_rate=0.01; error=8.0
# epoch=808; l_rate=0.01; error=10.0
# epoch=809; l_rate=0.01; error=12.0
# epoch=810; l_rate=0.01; error=10.0
# epoch=811; l_rate=0.01; error=13.0
# epoch=812; l_rate=0.01; error=10.0
# epoch=813; l_rate=0.01; error=7.0
# epoch=814; l_rate=0.01; error=14.0
# epoch=815; l_rate=0.01; error=18.0
# epoch=816; l_rate=0.01; error=8.0
# epoch=817; l_rate=0.01; error=7.0
# epoch=818; l_rate=0.01; error=11.0
# epoch=819; l_rate=0.01; error=5.0
# epoch=820; l_rate=0.01; error=8.0
# epoch=821; l_rate=0.01; error=8.0
# epoch=822; l_rate=0.01; error=8.0
# epoch=823; l_rate=0.01; error=11.0
# epoch=824; l_rate=0.01; error=14.0
# epoch=825; l_rate=0.01; error=7.0
# epoch=826; l_rate=0.01; error=13.0
# epoch=827; l_rate=0.01; error=10.0
# epoch=828; l_rate=0.01; error=4.0
# epoch=829; l_rate=0.01; error=10.0
# epoch=830; l_rate=0.01; error=11.0
# epoch=831; l_rate=0.01; error=15.0
# epoch=832; l_rate=0.01; error=15.0
# epoch=833; l_rate=0.01; error=13.0
# epoch=834; l_rate=0.01; error=10.0
# epoch=835; l_rate=0.01; error=10.0
# epoch=836; l_rate=0.01; error=10.0
# epoch=837; l_rate=0.01; error=6.0
# epoch=838; l_rate=0.01; error=7.0
# epoch=839; l_rate=0.01; error=9.0
# epoch=840; l_rate=0.01; error=11.0
# epoch=841; l_rate=0.01; error=17.0
# epoch=842; l_rate=0.01; error=12.0
# epoch=843; l_rate=0.01; error=7.0
# epoch=844; l_rate=0.01; error=7.0
# epoch=845; l_rate=0.01; error=9.0
# epoch=846; l_rate=0.01; error=6.0
# epoch=847; l_rate=0.01; error=9.0
# epoch=848; l_rate=0.01; error=13.0
# epoch=849; l_rate=0.01; error=12.0
# epoch=850; l_rate=0.01; error=13.0
# epoch=851; l_rate=0.01; error=14.0
# epoch=852; l_rate=0.01; error=10.0
# epoch=853; l_rate=0.01; error=14.0
# epoch=854; l_rate=0.01; error=14.0
# epoch=855; l_rate=0.01; error=10.0
# epoch=856; l_rate=0.01; error=10.0
# epoch=857; l_rate=0.01; error=16.0
# epoch=858; l_rate=0.01; error=10.0
# epoch=859; l_rate=0.01; error=10.0
# epoch=860; l_rate=0.01; error=14.0
# epoch=861; l_rate=0.01; error=16.0
# epoch=862; l_rate=0.01; error=14.0
# epoch=863; l_rate=0.01; error=10.0
# epoch=864; l_rate=0.01; error=10.0
# epoch=865; l_rate=0.01; error=8.0
# epoch=866; l_rate=0.01; error=5.0
# epoch=867; l_rate=0.01; error=15.0
# epoch=868; l_rate=0.01; error=12.0
# epoch=869; l_rate=0.01; error=10.0
# epoch=870; l_rate=0.01; error=8.0
# epoch=871; l_rate=0.01; error=16.0
# epoch=872; l_rate=0.01; error=10.0
# epoch=873; l_rate=0.01; error=12.0
# epoch=874; l_rate=0.01; error=12.0
# epoch=875; l_rate=0.01; error=8.0
# epoch=876; l_rate=0.01; error=16.0
# epoch=877; l_rate=0.01; error=12.0
# epoch=878; l_rate=0.01; error=8.0
# epoch=879; l_rate=0.01; error=16.0
# epoch=880; l_rate=0.01; error=14.0
# epoch=881; l_rate=0.01; error=12.0
# epoch=882; l_rate=0.01; error=14.0
# epoch=883; l_rate=0.01; error=14.0
# epoch=884; l_rate=0.01; error=14.0
# epoch=885; l_rate=0.01; error=6.0
# epoch=886; l_rate=0.01; error=9.0
# epoch=887; l_rate=0.01; error=10.0
# epoch=888; l_rate=0.01; error=14.0
# epoch=889; l_rate=0.01; error=12.0
# epoch=890; l_rate=0.01; error=12.0
# epoch=891; l_rate=0.01; error=12.0
# epoch=892; l_rate=0.01; error=16.0
# epoch=893; l_rate=0.01; error=14.0
# epoch=894; l_rate=0.01; error=17.0
# epoch=895; l_rate=0.01; error=10.0
# epoch=896; l_rate=0.01; error=12.0
# epoch=897; l_rate=0.01; error=5.0
# epoch=898; l_rate=0.01; error=5.0
# epoch=899; l_rate=0.01; error=3.0
# epoch=900; l_rate=0.01; error=9.0
# epoch=901; l_rate=0.01; error=6.0
# epoch=902; l_rate=0.01; error=10.0
# epoch=903; l_rate=0.01; error=7.0
# epoch=904; l_rate=0.01; error=8.0
# epoch=905; l_rate=0.01; error=14.0
# epoch=906; l_rate=0.01; error=7.0
# epoch=907; l_rate=0.01; error=5.0
# epoch=908; l_rate=0.01; error=7.0
# epoch=909; l_rate=0.01; error=12.0
# epoch=910; l_rate=0.01; error=14.0
# epoch=911; l_rate=0.01; error=16.0
# epoch=912; l_rate=0.01; error=12.0
# epoch=913; l_rate=0.01; error=12.0
# epoch=914; l_rate=0.01; error=10.0
# epoch=915; l_rate=0.01; error=10.0
# epoch=916; l_rate=0.01; error=16.0
# epoch=917; l_rate=0.01; error=14.0
# epoch=918; l_rate=0.01; error=10.0
# epoch=919; l_rate=0.01; error=16.0
# epoch=920; l_rate=0.01; error=18.0
# epoch=921; l_rate=0.01; error=12.0
# epoch=922; l_rate=0.01; error=16.0
# epoch=923; l_rate=0.01; error=18.0
# epoch=924; l_rate=0.01; error=7.0
# epoch=925; l_rate=0.01; error=7.0
# epoch=926; l_rate=0.01; error=7.0
# epoch=927; l_rate=0.01; error=9.0
# epoch=928; l_rate=0.01; error=12.0
# epoch=929; l_rate=0.01; error=10.0
# epoch=930; l_rate=0.01; error=12.0
# epoch=931; l_rate=0.01; error=14.0
# epoch=932; l_rate=0.01; error=9.0
# epoch=933; l_rate=0.01; error=13.0
# epoch=934; l_rate=0.01; error=16.0
# epoch=935; l_rate=0.01; error=12.0
# epoch=936; l_rate=0.01; error=9.0
# epoch=937; l_rate=0.01; error=6.0
# epoch=938; l_rate=0.01; error=10.0
# epoch=939; l_rate=0.01; error=10.0
# epoch=940; l_rate=0.01; error=8.0
# epoch=941; l_rate=0.01; error=8.0
# epoch=942; l_rate=0.01; error=8.0
# epoch=943; l_rate=0.01; error=14.0
# epoch=944; l_rate=0.01; error=14.0
# epoch=945; l_rate=0.01; error=7.0
# epoch=946; l_rate=0.01; error=14.0
# epoch=947; l_rate=0.01; error=14.0
# epoch=948; l_rate=0.01; error=12.0
# epoch=949; l_rate=0.01; error=11.0
# epoch=950; l_rate=0.01; error=14.0
# epoch=951; l_rate=0.01; error=9.0
# epoch=952; l_rate=0.01; error=10.0
# epoch=953; l_rate=0.01; error=10.0
# epoch=954; l_rate=0.01; error=8.0
# epoch=955; l_rate=0.01; error=4.0
# epoch=956; l_rate=0.01; error=3.0
# epoch=957; l_rate=0.01; error=5.0
# epoch=958; l_rate=0.01; error=8.0
# epoch=959; l_rate=0.01; error=7.0
# epoch=960; l_rate=0.01; error=11.0
# epoch=961; l_rate=0.01; error=4.0
# epoch=962; l_rate=0.01; error=5.0
# epoch=963; l_rate=0.01; error=9.0
# epoch=964; l_rate=0.01; error=16.0
# epoch=965; l_rate=0.01; error=10.0
# epoch=966; l_rate=0.01; error=12.0
# epoch=967; l_rate=0.01; error=9.0
# epoch=968; l_rate=0.01; error=7.0
# epoch=969; l_rate=0.01; error=10.0
# epoch=970; l_rate=0.01; error=8.0
# epoch=971; l_rate=0.01; error=6.0
# epoch=972; l_rate=0.01; error=8.0
# epoch=973; l_rate=0.01; error=12.0
# epoch=974; l_rate=0.01; error=5.0
# epoch=975; l_rate=0.01; error=14.0
# epoch=976; l_rate=0.01; error=11.0
# epoch=977; l_rate=0.01; error=17.0
# epoch=978; l_rate=0.01; error=10.0
# epoch=979; l_rate=0.01; error=16.0
# epoch=980; l_rate=0.01; error=16.0
# epoch=981; l_rate=0.01; error=10.0
# epoch=982; l_rate=0.01; error=16.0
# epoch=983; l_rate=0.01; error=12.0
# epoch=984; l_rate=0.01; error=12.0
# epoch=985; l_rate=0.01; error=10.0
# epoch=986; l_rate=0.01; error=10.0
# epoch=987; l_rate=0.01; error=7.0
# epoch=988; l_rate=0.01; error=9.0
# epoch=989; l_rate=0.01; error=5.0
# epoch=990; l_rate=0.01; error=9.0
# epoch=991; l_rate=0.01; error=14.0
# epoch=992; l_rate=0.01; error=12.0
# epoch=993; l_rate=0.01; error=14.0
# epoch=994; l_rate=0.01; error=14.0
# epoch=995; l_rate=0.01; error=7.0
# epoch=996; l_rate=0.01; error=18.0
# epoch=997; l_rate=0.01; error=12.0
# epoch=998; l_rate=0.01; error=12.0
# epoch=999; l_rate=0.01; error=10.0
# 'scores=[75.36231884057972, 75.36231884057972, 63.76811594202898]'
# 'mean accuracy=71.4975845410628'
